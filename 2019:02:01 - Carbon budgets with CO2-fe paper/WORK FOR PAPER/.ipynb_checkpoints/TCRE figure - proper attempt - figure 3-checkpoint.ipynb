# %%
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt

from scipy.io import readsav

from skimage.measure import EllipseModel
from matplotlib.patches import Ellipse

from scipy.ndimage import gaussian_filter

from matplotlib.patches import Patch
from matplotlib.lines import Line2D

import pyam

import pandas as pd

import sys
sys.path.append('/Users/stuartjenkins/Documents/$$Work/2019:02:01 - Carbon budgets with CO2-fe paper')
from fair_scm import *

# %%
E_0_100 = np.load('./output/E_s/2019_E_0_100.npy')
E_101_200 = np.load('./output/E_s/2019_E_101_200.npy')
E_201_300 = np.load('./output/E_s/2019_E_201_300.npy')
E_301_400 = np.load('./output/E_s/2019_E_301_400.npy')
E_401_500 = np.load('./output/E_s/2019_E_401_500.npy')
E_501_600 = np.load('./output/E_s/2019_E_501_600.npy')
E_601_700 = np.load('./output/E_s/2019_E_601_700.npy')
E_701_800 = np.load('./output/E_s/2019_E_701_800.npy')
E_801_900 = np.load('./output/E_s/2019_E_801_900.npy')
E_901_1000 = np.load('./output/E_s/2019_E_901_1000.npy')

data = readsav('./data/1750_Oct2017_forcings.idlsave')

# %%
gwi_0_100 = np.load('./output/gwi_s/2019_gwis_0_100.npy')
gwi_101_200 = np.load('./output/gwi_s/2019_gwis_101_200.npy')
gwi_201_300 = np.load('./output/gwi_s/2019_gwis_201_300.npy')
gwi_301_400 = np.load('./output/gwi_s/2019_gwis_301_400.npy')
gwi_401_500 = np.load('./output/gwi_s/2019_gwis_401_500.npy')
gwi_501_600 = np.load('./output/gwi_s/2019_gwis_501_600.npy')
gwi_601_700 = np.load('./output/gwi_s/2019_gwis_601_700.npy')
gwi_701_800 = np.load('./output/gwi_s/2019_gwis_701_800.npy')
gwi_801_900 = np.load('./output/gwi_s/2019_gwis_801_900.npy')
gwi_901_1000 = np.load('./output/gwi_s/2019_gwis_901_1000.npy')

# %%
E_total = E_0_100[...,0]
E_total = np.append(E_total, E_101_200[...,0], axis=1)
E_total = np.append(E_total, E_201_300[...,0], axis=1)
E_total = np.append(E_total, E_301_400[...,0], axis=1)
E_total = np.append(E_total, E_401_500[...,0], axis=1)
E_total = np.append(E_total, E_501_600[...,0], axis=1)
E_total = np.append(E_total, E_601_700[...,0], axis=1)
E_total = np.append(E_total, E_701_800[...,0], axis=1)
E_total = np.append(E_total, E_801_900[...,0], axis=1)
E_total = np.append(E_total, E_901_1000[...,0], axis=1)

G_total = np.cumsum(E_total, axis=0) - np.sum(E_total[:1871-1850], axis=0)

# %%
gwi_total = gwi_0_100
gwi_total = np.append(gwi_total, gwi_101_200, axis=2)
gwi_total = np.append(gwi_total, gwi_201_300, axis=2)
gwi_total = np.append(gwi_total, gwi_301_400, axis=2)
gwi_total = np.append(gwi_total, gwi_401_500, axis=2)
gwi_total = np.append(gwi_total, gwi_501_600, axis=2)
gwi_total = np.append(gwi_total, gwi_601_700, axis=2)
gwi_total = np.append(gwi_total, gwi_701_800, axis=2)
gwi_total = np.append(gwi_total, gwi_801_900, axis=2)
gwi_total = np.append(gwi_total, gwi_901_1000, axis=2)

# %%
awi_5thpercentile = np.percentile(gwi_total[:,0,:],5,axis=1)
awi_17thpercentile = np.percentile(gwi_total[:,0,:],17,axis=1)
awi_33thpercentile = np.percentile(gwi_total[:,0,:],33,axis=1)
awi_50thpercentile = np.percentile(gwi_total[:,0,:],50,axis=1)
awi_66thpercentile = np.percentile(gwi_total[:,0,:],66,axis=1)
awi_83thpercentile = np.percentile(gwi_total[:,0,:],83,axis=1)
awi_95thpercentile = np.percentile(gwi_total[:,0,:],95,axis=1)

nwi_5thpercentile = np.percentile(gwi_total[:,1,:],5,axis=1)
nwi_17thpercentile = np.percentile(gwi_total[:,1,:],17,axis=1)
nwi_33thpercentile = np.percentile(gwi_total[:,1,:],33,axis=1)
nwi_50thpercentile = np.percentile(gwi_total[:,1,:],50,axis=1)
nwi_66thpercentile = np.percentile(gwi_total[:,1,:],66,axis=1)
nwi_83thpercentile = np.percentile(gwi_total[:,1,:],83,axis=1)
nwi_95thpercentile = np.percentile(gwi_total[:,1,:],95,axis=1)

# np.save('output/gwi_s/gwi_percentiles/awi5thpercentile', awi_5thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi17thpercentile', awi_17thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi33thpercentile', awi_33thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi50thpercentile', awi_50thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi66thpercentile', awi_66thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi83thpercentile', awi_83thpercentile)
# np.save('output/gwi_s/gwi_percentiles/awi95thpercentile', awi_95thpercentile)

# np.save('output/gwi_s/gwi_percentiles/nwi5thpercentile', nwi_5thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi17thpercentile', nwi_17thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi33thpercentile', nwi_33thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi50thpercentile', nwi_50thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi66thpercentile', nwi_66thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi83thpercentile', nwi_83thpercentile)
# np.save('output/gwi_s/gwi_percentiles/nwi95thpercentile', nwi_95thpercentile)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0e9d640f7020> in <module>
# ----> 1 awi_5thpercentile = np.percentile(gwi_total[:,0,:],5,axis=1)
#       2 awi_17thpercentile = np.percentile(gwi_total[:,0,:],17,axis=1)
#       3 awi_33thpercentile = np.percentile(gwi_total[:,0,:],33,axis=1)
#       4 awi_50thpercentile = np.percentile(gwi_total[:,0,:],50,axis=1)
#       5 awi_66thpercentile = np.percentile(gwi_total[:,0,:],66,axis=1)
#
# ~/anaconda2/envs/python37/lib/python3.7/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3538         raise ValueError("Percentiles must be in the range [0, 100]")
#    3539     return _quantile_unchecked(
# -> 3540         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3541
#    3542
#
# ...

# %%
E_5thpercentile = np.percentile(E_total,5,axis=1)
E_17thpercentile = np.percentile(E_total,17,axis=1)
E_33thpercentile = np.percentile(E_total,33,axis=1)
E_50thpercentile = np.percentile(E_total,50,axis=1)
E_66thpercentile = np.percentile(E_total,66,axis=1)
E_83thpercentile = np.percentile(E_total,83,axis=1)
E_95thpercentile = np.percentile(E_total,95,axis=1)

G_5thpercentile = np.cumsum(E_5thpercentile) - np.sum(E_5thpercentile[:1871-1850])
G_17thpercentile = np.cumsum(E_17thpercentile) - np.sum(E_17thpercentile[:1871-1850])
G_33thpercentile = np.cumsum(E_33thpercentile) - np.sum(E_33thpercentile[:1871-1850])
G_50thpercentile = np.cumsum(E_50thpercentile) - np.sum(E_50thpercentile[:1871-1850])
G_66thpercentile = np.cumsum(E_66thpercentile) - np.sum(E_66thpercentile[:1871-1850])
G_83thpercentile = np.cumsum(E_83thpercentile) - np.sum(E_83thpercentile[:1871-1850])
G_95thpercentile = np.cumsum(E_95thpercentile) - np.sum(E_95thpercentile[:1871-1850])

# np.save('output/E_s/E_percentiles/E5thpercentile', E_5thpercentile)
# np.save('output/E_s/E_percentiles/E17thpercentile', E_17thpercentile)
# np.save('output/E_s/E_percentiles/E33thpercentile', E_33thpercentile)
# np.save('output/E_s/E_percentiles/E50thpercentile', E_50thpercentile)
# np.save('output/E_s/E_percentiles/E66thpercentile', E_66thpercentile)
# np.save('output/E_s/E_percentiles/E83thpercentile', E_83thpercentile)
# np.save('output/E_s/E_percentiles/E95thpercentile', E_95thpercentile)

# np.save('output/E_s/E_percentiles/G5thpercentile', G_5thpercentile)
# np.save('output/E_s/E_percentiles/G17thpercentile', G_17thpercentile)
# np.save('output/E_s/E_percentiles/G33thpercentile', G_33thpercentile)
# np.save('output/E_s/E_percentiles/G50thpercentile', G_50thpercentile)
# np.save('output/E_s/E_percentiles/G66thpercentile', G_66thpercentile)
# np.save('output/E_s/E_percentiles/G83thpercentile', G_83thpercentile)
# np.save('output/E_s/E_percentiles/G95thpercentile', G_95thpercentile)

# %%
AnthroRF_5thpercentile = np.percentile(data['rf_anthro'], 5, axis=1)
AnthroRF_17thpercentile = np.percentile(data['rf_anthro'], 17, axis=1)
AnthroRF_33thpercentile = np.percentile(data['rf_anthro'], 33, axis=1)
AnthroRF_50thpercentile = np.percentile(data['rf_anthro'], 50, axis=1)
AnthroRF_66thpercentile = np.percentile(data['rf_anthro'], 66, axis=1)
AnthroRF_83thpercentile = np.percentile(data['rf_anthro'], 83, axis=1)
AnthroRF_95thpercentile = np.percentile(data['rf_anthro'], 95, axis=1)

NatRF_5thpercentile = np.percentile(data['rf_nat'], 5, axis=1)
NatRF_17thpercentile = np.percentile(data['rf_nat'], 17, axis=1)
NatRF_33thpercentile = np.percentile(data['rf_nat'], 33, axis=1)
NatRF_50thpercentile = np.percentile(data['rf_nat'], 50, axis=1)
NatRF_66thpercentile = np.percentile(data['rf_nat'], 66, axis=1)
NatRF_83thpercentile = np.percentile(data['rf_nat'], 83, axis=1)
NatRF_95thpercentile = np.percentile(data['rf_nat'], 95, axis=1)

# np.save('output/RF_percentiles/AnthroRF5thpercentile', AnthroRF_5thpercentile)
# np.save('output/RF_percentiles/AnthroRF17thpercentile', AnthroRF_17thpercentile)
# np.save('output/RF_percentiles/AnthroRF33thpercentile', AnthroRF_33thpercentile)
# np.save('output/RF_percentiles/AnthroRF50thpercentile', AnthroRF_50thpercentile)
# np.save('output/RF_percentiles/AnthroRF66thpercentile', AnthroRF_66thpercentile)
# np.save('output/RF_percentiles/AnthroRF83thpercentile', AnthroRF_83thpercentile)
# np.save('output/RF_percentiles/AnthroRF95thpercentile', AnthroRF_95thpercentile)

# np.save('output/RF_percentiles/NatRF5thpercentile', NatRF_5thpercentile )
# np.save('output/RF_percentiles/NatRF17thpercentile', NatRF_17thpercentile)
# np.save('output/RF_percentiles/NatRF33thpercentile', NatRF_33thpercentile)
# np.save('output/RF_percentiles/NatRF50thpercentile', NatRF_50thpercentile)
# np.save('output/RF_percentiles/NatRF66thpercentile', NatRF_66thpercentile)
# np.save('output/RF_percentiles/NatRF83thpercentile', NatRF_83thpercentile)
# np.save('output/RF_percentiles/NatRF95thpercentile', NatRF_95thpercentile)

# %%
# for i in range(0,20000,2000):
#     plt.plot(np.arange(1850,2018), E_total[:,i])
    
fig, ax = plt.subplots(2,2, figsize=(15,15))
ax[0,0].set_xlabel('Year', fontsize = 13)
ax[0,1].set_xlabel('Year', fontsize = 13)
ax[1,0].set_xlabel('Year', fontsize = 13)
ax[1,1].set_xlabel('Year', fontsize = 13)

ax[0,0].set_ylabel('RF (W/m$^2$)', fontsize = 13)
ax[0,1].set_ylabel('Annual Emissions (GtC-fe/yr)', fontsize = 13)
ax[1,0].set_ylabel('Cumulative Emissions (GtC-fe)', fontsize = 13)
ax[1,1].set_ylabel('Warming relative to 1850-1900 ($^{\circ}$C)', fontsize = 13)

ax[0,0].tick_params(labelsize=13)
ax[0,1].tick_params(labelsize=13)
ax[1,0].tick_params(labelsize=13)
ax[1,1].tick_params(labelsize=13)


E_5 = np.percentile(E_total,5,axis=1)
E_95 = np.percentile(E_total,95,axis=1)
E_50 = np.percentile(E_total,50,axis=1)
    
E_5 = gaussian_filter(E_5, 2, mode='nearest')
E_50 = gaussian_filter(E_50, 2, mode='nearest')
E_95 = gaussian_filter(E_95, 2, mode='nearest')

ax[0,1].fill_between(np.arange(1850,2018), E_5, E_95, color = 'black', alpha=0.3)
ax[0,1].plot(np.arange(1850,2018), E_50, color = 'black', linewidth=3)

ax[1,0].plot(np.arange(1850,2018), np.cumsum(np.percentile(E_total,50,axis=1)), color = 'black', linewidth=3)
ax[1,0].fill_between(np.arange(1850,2018), np.cumsum(np.percentile(E_total,5,axis=1)), np.cumsum(np.percentile(E_total,95,axis=1)), color = 'black', alpha=0.3)

ax[0,0].fill_between(data['year'], np.percentile(data['rf_anthro'], 5, axis=1), np.percentile(data['rf_anthro'], 95, axis=1), color='orange', alpha=0.3)
ax[0,0].plot(data['year'], np.percentile(data['rf_anthro'], 50, axis=1), color='orange')

ax[0,0].fill_between(data['year'], np.percentile(data['rf_nat'], 5, axis=1), np.percentile(data['rf_nat'], 95, axis=1), color='darkblue', alpha=0.3)
ax[0,0].plot(data['year'], np.percentile(data['rf_nat'], 50, axis=1), color='darkblue')

ax[1,1].fill_between(np.arange(1850,2018), np.percentile(gwi_total[:,0,:],5,axis=1), np.percentile(gwi_total[:,0,:],95,axis=1), color='orange', alpha=0.3)
ax[1,1].plot(np.arange(1850,2018), np.percentile(gwi_total[:,0,:],50,axis=1), color='orange', linewidth=3)
ax[1,1].fill_between(np.arange(1850,2018), np.percentile(gwi_total[:,1,:],5,axis=1), np.percentile(gwi_total[:,1,:],95,axis=1), color='darkblue', alpha=0.3)
ax[1,1].plot(np.arange(1850,2018), np.percentile(gwi_total[:,1,:],50,axis=1), color='darkblue', linewidth=3)

obs = np.genfromtxt('./data/mean_obs_2019_updates.txt')

# print(temp_obs.shape)
# obs = obs_temps
obs_years = np.arange(1850,2019,1/12)
base_low = 1850.
base_high = 1900
obs = obs - np.mean(obs[np.logical_and(obs_years>=base_low,obs_years<(base_high+1))])
ax[1,1].plot(obs_years, obs, color='black', linewidth=1, zorder=-1, alpha=0.4)

ax[0,0].text(1750,2.5,'a)', fontsize=17, fontweight='bold')
ax[0,1].text(1850,20,'b)', fontsize=17, fontweight='bold')
ax[1,0].text(1850,1150,'c)', fontsize=17, fontweight='bold')
ax[1,1].text(1850,1.25,'d)', fontsize=17, fontweight='bold')

# fig.savefig('2019_other_bits.pdf', dpi=300)
# Out:
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c

# %%
# print(np.percentile(gwi_total[-12*5:,0,:],95,axis=1))

# best estimate = 1.10 C
# 5-95th percentile = 0.98 C - 1.28 C

# %%
TCREs_most_recent_decade = np.load('output/TCRE_s/2019_TCREs_0_100.npy')
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_101_200.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_201_300.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_301_400.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_401_500.npy')) 
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_501_600.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_601_700.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_701_800.npy'))  
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_801_900.npy')) 
TCREs_most_recent_decade = np.append(TCREs_most_recent_decade, np.load('output/TCRE_s/2019_TCREs_901_1000.npy')) 

print(np.percentile(TCREs_most_recent_decade, 5)*1000)
print(np.percentile(TCREs_most_recent_decade, 33)*1000)
print(np.percentile(TCREs_most_recent_decade, 50)*1000)
print(np.percentile(TCREs_most_recent_decade, 66)*1000)
print(np.percentile(TCREs_most_recent_decade, 95)*1000)
# Out:
# 0.8568687228490058
# 1.147982205217411
# 1.2979644550343596
# 1.4826275431550529
# 2.4866489078289575

# %%
TCRE_05 = 0.86
TCRE_33 = 1.15
TCRE_50 = 1.30
TCRE_66 = 1.48
TCRE_95 = 2.49

# print((0.45*1000/TCRE_05)*44/12)
# print((0.45*1000/TCRE_95)*44/12)

# for mid-range non-CO2 contribution (240GtCO2-fe)
co2_budget_min = 450
co2_budget_max = 1770

total_budget_33 = 0.4*1000*44/(TCRE_33*12)
total_budget_50 = 0.4*1000*44/(TCRE_50*12)
total_budget_66 = 0.4*1000*44/(TCRE_66*12)
total_budget_95 = 0.4*1000*44/(TCRE_95*12)
total_budget_05 = 0.4*1000*44/(TCRE_05*12)

print(total_budget_05, total_budget_95)
print(total_budget_33, total_budget_50, total_budget_66)

co2_budget_05 = total_budget_05 - 240
co2_budget_33 = total_budget_33 - 240
co2_budget_50 = total_budget_50 - 240
co2_budget_66 = total_budget_66 - 240
co2_budget_95 = total_budget_95 - 240
print(co2_budget_05,co2_budget_33,co2_budget_50,co2_budget_66,co2_budget_95)


# noaa = np.genfromtxt('data/temp_obs_2019/noaa_monthly.csv', delimiter=',')
# hadcrut4 = np.genfromtxt('data/temp_obs_2019/hadcrut4_monthly.txt')
# cowtanway = np.genfromtxt('data/temp_obs_2019/cowtan_way_monthly.txt', delimiter='   ')
# gistemp = np.genfromtxt('data/temp_obs_2019/GISTEMP_monthly.csv', delimiter=',')

# noaa_all = np.zeros(((2019-1880)*12,2))
# noaa_all[:,0] = np.arange(1880,2019,1/12)
# noaa_all[:,1] = noaa[:-10,1]
# plt.plot(noaa_all[:,0], noaa_all[:,1], color='black')

# hadcrut4_all = np.zeros((hadcrut4.shape[0]*6, 2))
# hadcrut4_all[:,0] = np.arange(1850,2019,1/12)
# for i in range(0,hadcrut4.shape[0]):
#     if i % 2 == 0:
#         hadcrut4_all[int(i/2)*12:(int(i/2)+1)*12,1] = hadcrut4[i,1:]

# plt.plot(hadcrut4_all[:,0], hadcrut4_all[:,1], color='blue')        
        
# cowtanway[:,0] = np.arange(1850,2019,1/12)
# plt.plot(cowtanway[:,0], cowtanway[:,1], color='red')

# gistemp_all = np.zeros(((2019-1880)*12,2))
# gistemp_all[:,0] = np.arange(1880,2019,1/12)
# for i in range(1,gistemp.shape[0]-2):
#     gistemp_all[i*12:(i+1)*12,1] = gistemp[i,1:13]
    
# plt.plot(gistemp_all[:,0], gistemp_all[:,1], color='green')

# plt.figure()

# com_ref_low = 1880
# com_ref_high = 2018
# base_low = 1850
# base_high = 1900

# hadcrut4_all[:,1] = hadcrut4_all[:,1] - np.mean(hadcrut4_all[(hadcrut4_all[:,0]>=base_low)*(hadcrut4_all[:,0]<base_high+1), 1])
# offset = np.mean(hadcrut4_all[12*(1880-1850):,1])

# cowtanway[:,1] = cowtanway[:,1] - np.mean(cowtanway[(cowtanway[:,0]>=base_low)*(cowtanway[:,0]<base_high+1), 1])

# noaa_all = noaa_all - np.mean(noaa_all[(noaa_all[:,0]>=com_ref_low)*(noaa_all[:,0]<com_ref_low+1), 1]) + offset
# gistemp_all = gistemp_all - np.mean(gistemp_all[(gistemp_all[:,0]>=com_ref_low)*(gistemp_all[:,0]<com_ref_low+1), 1]) + offset

# plt.plot(cowtanway[:,0], cowtanway[:,1], color='red')
# plt.plot(noaa_all[:,0], noaa_all[:,1], color='black')
# plt.plot(gistemp_all[:,0], gistemp_all[:,1], color='green')
# plt.plot(hadcrut4_all[:,0], hadcrut4_all[:,1], color='blue')

# mean_temp = np.zeros((2019-1850)*12)
# for i in range(0,(2019-1850)*12):
#     if i < (1880-1850)*12:
#         mean_temp[i] = np.mean([hadcrut4_all[i,1], cowtanway[i,1]])
#     else:
#         mean_temp[i] = np.mean([hadcrut4_all[i,1], cowtanway[i,1], gistemp_all[i-30*12,1], noaa_all[i-30*12,1]])
    
# plt.plot(np.arange(1850,2019,1/12), mean_temp, color='orange')

# print(np.mean(mean_temp[-12:]))

# # np.savetxt('mean_obs_2019_updates.txt', mean_temp)
# Out:
# 1705.4263565891472 589.0227576974564
# 1275.3623188405797 1128.2051282051282 990.9909909909911
# 1465.4263565891472 1035.3623188405797 888.2051282051282 750.9909909909911 349.0227576974564

# %%
conditions_0_100 = np.load('output/conditions/conditions_0_100.npy')
conditions_101_200 = np.load('output/conditions/conditions_101_200.npy') 
conditions_201_300 = np.load('output/conditions/conditions_201_300.npy') 
conditions_301_400 = np.load('output/conditions/conditions_301_400.npy') 
conditions_401_500 = np.load('output/conditions/conditions_401_500.npy')
conditions_501_600 = np.load('output/conditions/conditions_501_600.npy') 
conditions_601_700 = np.load('output/conditions/conditions_601_700.npy') 
conditions_701_800 = np.load('output/conditions/conditions_701_800.npy') 
conditions_801_900 = np.load('output/conditions/conditions_801_900.npy')
conditions_901_1000 = np.load('output/conditions/conditions_901_1000.npy')

conditions_total = np.array([])
conditions_total = np.append(conditions_0_100, conditions_101_200)
conditions_total = np.append(conditions_total, conditions_201_300)
conditions_total = np.append(conditions_total, conditions_301_400)
conditions_total = np.append(conditions_total, conditions_401_500)
conditions_total = np.append(conditions_total, conditions_501_600)
conditions_total = np.append(conditions_total, conditions_601_700)
conditions_total = np.append(conditions_total, conditions_701_800)
conditions_total = np.append(conditions_total, conditions_801_900)
conditions_total = np.append(conditions_total, conditions_901_1000)

# %%
# fig_1, ax_1 = plt.subplots(figsize=(10,10))
# ax_1.set_xlim(0,1200)
# ax_1.set_ylim(0,1.4)

# G_present_decade = np.mean(G_total[-10:,:], axis=0)
# awi_present_decade = np.mean(gwi_total[-10:,0,:], axis=0)

# # print(G_present_decade.size)
# # print(awi_present_decade.shape[0])

# G_present_decade_all = np.zeros(awi_present_decade.size)
# for i in range(0,G_present_decade.size):
#     G_present_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_present_decade[i]

# G_present_decade_5_95 = G_present_decade_all[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]
# awi_present_decade_5_95 = awi_present_decade[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]

# # for i in range(0,G_present_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_present_decade[i])[::5], (awi_present_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='darkred')
    
# for i in range(0,G_present_decade_5_95.size,5000):
#     ax_1.scatter(G_present_decade_5_95[i], awi_present_decade_5_95[i], color='indianred', alpha=0.5)

    
# x = G_present_decade_5_95[::5000]
# y = awi_present_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell = EllipseModel()
# ell.estimate(a_points)

# xc, yc, a, b, theta = ell.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='indianred', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch)   
    
    
    
    
    
    
# G_00s_decade = np.mean(G_total[2000-1850:2011-1850,:], axis=0)
# awi_00s_decade = np.mean(gwi_total[2000-1850:2011-1850,0,:], axis=0)

# # print(G_00s_decade.size)
# # print(awi_00s_decade.shape[0])

# # for i in range(0,G_00s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_00s_decade[i])[::5], (awi_00s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='indianred')

# G_00s_decade_all = np.zeros(awi_00s_decade.size)
# for i in range(0,G_00s_decade.size):
#     G_00s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_00s_decade[i]

# G_00s_decade_5_95 = G_00s_decade_all[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]
# awi_00s_decade_5_95 = awi_00s_decade[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]

# for i in range(0,G_00s_decade_5_95.size,5000):
#     ax_1.scatter(G_00s_decade_5_95[i], awi_00s_decade_5_95[i], color='darkred', alpha=0.5)  
    
# x = G_00s_decade_5_95[::5000]
# y = awi_00s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell2 = EllipseModel()
# ell2.estimate(a_points)

# xc, yc, a, b, theta = ell2.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch2 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='darkred', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch2) 




    
    
# G_90s_decade = np.mean(G_total[1990-1850:2001-1850,:], axis=0)
# awi_90s_decade = np.mean(gwi_total[1990-1850:2001-1850,0,:], axis=0)

# # print(G_90s_decade.size)
# # print(awi_90s_decade.shape[0])

# # for i in range(0,G_90s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_90s_decade[i])[::5], (awi_90s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='red')

# G_90s_decade_all = np.zeros(awi_90s_decade.size)
# for i in range(0,G_90s_decade.size):
#     G_90s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_90s_decade[i]

# G_90s_decade_5_95 = G_90s_decade_all[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]
# awi_90s_decade_5_95 = awi_90s_decade[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]

# for i in range(0,G_90s_decade_5_95.size,5000):
#     ax_1.scatter(G_90s_decade_5_95[i], awi_90s_decade_5_95[i], color='red', alpha=0.5)  
    
# x = G_90s_decade_5_95[::5000]
# y = awi_90s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell3 = EllipseModel()
# ell3.estimate(a_points)

# xc, yc, a, b, theta = ell3.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch3 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='red', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch3) 




    
    
# G_80s_decade = np.mean(G_total[1980-1850:1991-1850,:], axis=0)
# awi_80s_decade = np.mean(gwi_total[1980-1850:1991-1850,0,:], axis=0)

# # print(G_80s_decade.size)
# # print(awi_80s_decade.shape[0])

# # for i in range(0,G_80s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_80s_decade[i])[::5], (awi_80s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='coral')

# G_80s_decade_all = np.zeros(awi_80s_decade.size)
# for i in range(0,G_80s_decade.size):
#     G_80s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_80s_decade[i]

# G_80s_decade_5_95 = G_80s_decade_all[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]
# awi_80s_decade_5_95 = awi_80s_decade[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]

# for i in range(0,G_80s_decade_5_95.size,5000):
#     ax_1.scatter(G_80s_decade_5_95[i], awi_80s_decade_5_95[i], color='coral', alpha=0.5)  

# x = G_80s_decade_5_95[::5000]
# y = awi_80s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell4 = EllipseModel()
# ell4.estimate(a_points)

# xc, yc, a, b, theta = ell4.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch4 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='coral', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch4)





# G_70s_decade = np.mean(G_total[1970-1850:1981-1850,:], axis=0)
# awi_70s_decade = np.mean(gwi_total[1970-1850:1981-1850,0,:], axis=0)

# # print(G_70s_decade.size)
# # print(awi_70s_decade.shape[0])

# # for i in range(0,G_70s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

# G_70s_decade_all = np.zeros(awi_70s_decade.size)
# for i in range(0,G_70s_decade.size):
#     G_70s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_70s_decade[i]

# G_70s_decade_5_95 = G_70s_decade_all[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]
# awi_70s_decade_5_95 = awi_70s_decade[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]

# for i in range(0,G_70s_decade_5_95.size,5000):
#     ax_1.scatter(G_70s_decade_5_95[i], awi_70s_decade_5_95[i], color='orange', alpha=0.5)  

# x = G_70s_decade_5_95[::5000]
# y = awi_70s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell5 = EllipseModel()
# ell5.estimate(a_points)

# xc, yc, a, b, theta = ell5.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch5 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='orange', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch5)
    
    
    
    
    
    
# G_60s_decade = np.mean(G_total[1960-1850:1971-1850,:], axis=0)
# awi_60s_decade = np.mean(gwi_total[1960-1850:1971-1850,0,:], axis=0)

# # print(G_60s_decade.size)
# # print(awi_60s_decade.shape[0])

# # for i in range(0,G_70s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

# G_60s_decade_all = np.zeros(awi_60s_decade.size)
# for i in range(0,G_60s_decade.size):
#     G_60s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_60s_decade[i]

# G_60s_decade_5_95 = G_60s_decade_all[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]
# awi_60s_decade_5_95 = awi_60s_decade[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]

# for i in range(0,G_60s_decade_5_95.size,5000):
#     ax_1.scatter(G_60s_decade_5_95[i], awi_60s_decade_5_95[i], color='gold', alpha=0.5)  
    
# x = G_60s_decade_5_95[::5000]
# y = awi_60s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell6 = EllipseModel()
# ell6.estimate(a_points)

# xc, yc, a, b, theta = ell6.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    

# # using this exact set up on a and b to convert a 1 sigma ellipse on the points to a 5-95th percentile one!!!
# ell_patch6 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='gold', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch6)    
    
    
    
    
    

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.2, zorder=-1)
# ax_1.plot(np.array([0,1200]), np.array([0,1200])*1.25*0.001, color='black', linewidth=3, zorder=10)


# ax_1.set_xlim(0,1200)
# ax_1.set_ylim(0,1.5)
# ax_1.set_xlabel('Cumulative emissions (TtCO$_2$-fe)', fontsize=18)
# ax_1.set_ylabel('Temperature anomaly ($^{\circ}$C rel. to 1850-1900)', fontsize=18)
# ax_1.tick_params(labelsize=18)

# # TCRE range:
# # 5th: 0.82
# # 50th: 1.25
# # 95th: 2.39
# # mean = 1.37

# # fig_1.savefig('TCRE_full_uncertainties_5_95_ellipses.pdf', dpi=400)

# %%
# fig_1, ax_1 = plt.subplots(figsize=(10,10))
# ax_1.set_xlim(0,1200)
# ax_1.set_ylim(0,1.4)

# G_present_decade = np.mean(G_total[-10:,:], axis=0)
# awi_present_decade = np.mean(gwi_total[-10:,0,:], axis=0)

# # print(G_present_decade.size)
# # print(awi_present_decade.shape[0])

# G_present_decade_all = np.zeros(awi_present_decade.size)
# for i in range(0,G_present_decade.size):
#     G_present_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_present_decade[i]

# G_present_decade_5_95 = G_present_decade_all[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]
# awi_present_decade_5_95 = awi_present_decade[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]

# # for i in range(0,G_present_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_present_decade[i])[::5], (awi_present_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='darkred')
    
# for i in range(0,G_present_decade_5_95.size,5000):
#     ax_1.scatter(G_present_decade_5_95[i], awi_present_decade_5_95[i], color='indianred', alpha=0.5)

    
# x = G_present_decade_5_95[::5000]
# y = awi_present_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell = EllipseModel()
# ell.estimate(a_points)

# xc, yc, a, b, theta = ell.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='indianred', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch)   
    
    
    
    
    
    
# G_00s_decade = np.mean(G_total[2000-1850:2011-1850,:], axis=0)
# awi_00s_decade = np.mean(gwi_total[2000-1850:2011-1850,0,:], axis=0)

# # print(G_00s_decade.size)
# # print(awi_00s_decade.shape[0])

# # for i in range(0,G_00s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_00s_decade[i])[::5], (awi_00s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='indianred')

# G_00s_decade_all = np.zeros(awi_00s_decade.size)
# for i in range(0,G_00s_decade.size):
#     G_00s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_00s_decade[i]

# G_00s_decade_5_95 = G_00s_decade_all[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]
# awi_00s_decade_5_95 = awi_00s_decade[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]

# for i in range(0,G_00s_decade_5_95.size,5000):
#     ax_1.scatter(G_00s_decade_5_95[i], awi_00s_decade_5_95[i], color='darkred', alpha=0.5)  
    
# x = G_00s_decade_5_95[::5000]
# y = awi_00s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell2 = EllipseModel()
# ell2.estimate(a_points)

# xc, yc, a, b, theta = ell2.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch2 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='darkred', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch2) 




    
    
# G_90s_decade = np.mean(G_total[1990-1850:2001-1850,:], axis=0)
# awi_90s_decade = np.mean(gwi_total[1990-1850:2001-1850,0,:], axis=0)

# # print(G_90s_decade.size)
# # print(awi_90s_decade.shape[0])

# # for i in range(0,G_90s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_90s_decade[i])[::5], (awi_90s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='red')

# G_90s_decade_all = np.zeros(awi_90s_decade.size)
# for i in range(0,G_90s_decade.size):
#     G_90s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_90s_decade[i]

# G_90s_decade_5_95 = G_90s_decade_all[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]
# awi_90s_decade_5_95 = awi_90s_decade[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]

# for i in range(0,G_90s_decade_5_95.size,5000):
#     ax_1.scatter(G_90s_decade_5_95[i], awi_90s_decade_5_95[i], color='red', alpha=0.5)  
    
# x = G_90s_decade_5_95[::5000]
# y = awi_90s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell3 = EllipseModel()
# ell3.estimate(a_points)

# xc, yc, a, b, theta = ell3.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch3 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='red', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch3) 




    
    
# G_80s_decade = np.mean(G_total[1980-1850:1991-1850,:], axis=0)
# awi_80s_decade = np.mean(gwi_total[1980-1850:1991-1850,0,:], axis=0)

# # print(G_80s_decade.size)
# # print(awi_80s_decade.shape[0])

# # for i in range(0,G_80s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_80s_decade[i])[::5], (awi_80s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='coral')

# G_80s_decade_all = np.zeros(awi_80s_decade.size)
# for i in range(0,G_80s_decade.size):
#     G_80s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_80s_decade[i]

# G_80s_decade_5_95 = G_80s_decade_all[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]
# awi_80s_decade_5_95 = awi_80s_decade[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]

# for i in range(0,G_80s_decade_5_95.size,5000):
#     ax_1.scatter(G_80s_decade_5_95[i], awi_80s_decade_5_95[i], color='coral', alpha=0.5)  

# x = G_80s_decade_5_95[::5000]
# y = awi_80s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell4 = EllipseModel()
# ell4.estimate(a_points)

# xc, yc, a, b, theta = ell4.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch4 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='coral', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch4)





# G_70s_decade = np.mean(G_total[1970-1850:1981-1850,:], axis=0)
# awi_70s_decade = np.mean(gwi_total[1970-1850:1981-1850,0,:], axis=0)

# # print(G_70s_decade.size)
# # print(awi_70s_decade.shape[0])

# # for i in range(0,G_70s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

# G_70s_decade_all = np.zeros(awi_70s_decade.size)
# for i in range(0,G_70s_decade.size):
#     G_70s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_70s_decade[i]

# G_70s_decade_5_95 = G_70s_decade_all[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]
# awi_70s_decade_5_95 = awi_70s_decade[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]

# for i in range(0,G_70s_decade_5_95.size,5000):
#     ax_1.scatter(G_70s_decade_5_95[i], awi_70s_decade_5_95[i], color='orange', alpha=0.5)  

# x = G_70s_decade_5_95[::5000]
# y = awi_70s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell5 = EllipseModel()
# ell5.estimate(a_points)

# xc, yc, a, b, theta = ell5.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    
# ell_patch5 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='orange', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch5)
    
    
    
    
    
    
# G_60s_decade = np.mean(G_total[1960-1850:1971-1850,:], axis=0)
# awi_60s_decade = np.mean(gwi_total[1960-1850:1971-1850,0,:], axis=0)

# # print(G_60s_decade.size)
# # print(awi_60s_decade.shape[0])

# # for i in range(0,G_70s_decade.size,250):
# #     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

# G_60s_decade_all = np.zeros(awi_60s_decade.size)
# for i in range(0,G_60s_decade.size):
#     G_60s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_60s_decade[i]

# G_60s_decade_5_95 = G_60s_decade_all[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]
# awi_60s_decade_5_95 = awi_60s_decade[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]

# for i in range(0,G_60s_decade_5_95.size,5000):
#     ax_1.scatter(G_60s_decade_5_95[i], awi_60s_decade_5_95[i], color='gold', alpha=0.5)  
    
# x = G_60s_decade_5_95[::5000]
# y = awi_60s_decade_5_95[::5000]
# a_points = np.zeros((x.size,2))
# a_points[:,0] = x
# a_points[:,1] = y

# ell6 = EllipseModel()
# ell6.estimate(a_points)

# xc, yc, a, b, theta = ell6.params

# print("center = ",  (xc, yc))
# print("angle of rotation = ",  theta)
# print("axes = ", (a,b))  
    
# # ax_1.scatter(xc, yc, color='blue', s=100)    

# # using this exact set up on a and b to convert a 1 sigma ellipse on the points to a 5-95th percentile one!!!
# ell_patch6 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='gold', facecolor='none', zorder=10, linewidth=3)
# ax_1.add_patch(ell_patch6)    
    
    
    
    
    

# # ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), [0,0], np.array([0,1200])*0.89*0.001, color='black', alpha=0.1, zorder=-1)
# # ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*0.89*0.001, color='black', alpha=0.1, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.89*0.001, np.array([0,1200])*1.0*0.001, color='black', alpha=0.15, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.0*0.001, np.array([0,1200])*1.08*0.001, color='black', alpha=0.2, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.08*0.001, np.array([0,1200])*1.16*0.001, color='black', alpha=0.25, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.16*0.001, np.array([0,1200])*1.25*0.001, color='black', alpha=0.3, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.25*0.001, np.array([0,1200])*1.35*0.001, color='black', alpha=0.35, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.35*0.001, np.array([0,1200])*1.48*0.001, color='black', alpha=0.4, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.48*0.001, np.array([0,1200])*1.69*0.001, color='black', alpha=0.45, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.69*0.001, np.array([0,1200])*2.04*0.001, color='black', alpha=0.5, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*2.04*0.001, np.array([0,1200])*10000000000, color='black', alpha=0.55, zorder=-1)

# # ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=0)

# ax_1.plot(np.array([0,1200]), np.array([0,1200])*1.25*0.001, color='black', linewidth=5, zorder=10)

# # ax_1.plot(np.array([0,1200]), np.array([0,1200])*0.89*0.001, color='white', zorder=0)

# # ax_1.text(,,'')

# ax_1.set_xlim(0,1200)
# ax_1.set_ylim(0,1.5)
# ax_1.set_xlabel('Cumulative emissions (TtCO$_2$-fe)', fontsize=18)
# ax_1.set_ylabel('Temperature anomaly ($^{\circ}$C rel. to 1850-1900)', fontsize=18)
# ax_1.tick_params(labelsize=18)

# # TCRE range:
# # 5th: 0.82
# # 50th: 1.25
# # 95th: 2.39
# # mean = 1.37

# # fig_1.savefig('TCRE_full_uncertainties_5_95_ellipses.pdf', dpi=400)

# %%
# fig_1, ax_1 = plt.subplots(figsize=(10,10))
fig_1 = plt.figure(figsize=(11,6))
ax_1 = fig_1.add_axes([0.1,0.1,0.43,0.85])
ax_peak = fig_1.add_axes([0.6,0.57,0.36,0.38])
ax_peak2 = fig_1.add_axes([0.6,0.1,0.36,0.38])
ax_1.set_xlim(0,1200)
ax_1.set_ylim(0,1.4)

G_present_decade = np.mean(G_total[-10:,:], axis=0)
awi_present_decade = np.mean(gwi_total[-10:,0,:], axis=0)

# print(G_present_decade.size)
# print(awi_present_decade.shape[0])

G_present_decade_all = np.zeros(awi_present_decade.size)
for i in range(0,G_present_decade.size):
    G_present_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_present_decade[i]

G_present_decade_5_95 = G_present_decade_all[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]
awi_present_decade_5_95 = awi_present_decade[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]

# for i in range(0,G_present_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_present_decade[i])[::5], (awi_present_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='darkred')
    
for i in range(0,G_present_decade_5_95.size,5000):
    ax_1.scatter(G_present_decade_5_95[i], awi_present_decade_5_95[i], color='indianred', alpha=0.5)

    
x = G_present_decade_5_95[::5000]
y = awi_present_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell = EllipseModel()
ell.estimate(a_points)

xc, yc, a, b, theta = ell.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='indianred', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch)   
    
    
    
    
    
    
G_00s_decade = np.mean(G_total[2000-1850:2011-1850,:], axis=0)
awi_00s_decade = np.mean(gwi_total[2000-1850:2011-1850,0,:], axis=0)

# print(G_00s_decade.size)
# print(awi_00s_decade.shape[0])

# for i in range(0,G_00s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_00s_decade[i])[::5], (awi_00s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='indianred')

G_00s_decade_all = np.zeros(awi_00s_decade.size)
for i in range(0,G_00s_decade.size):
    G_00s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_00s_decade[i]

G_00s_decade_5_95 = G_00s_decade_all[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]
awi_00s_decade_5_95 = awi_00s_decade[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]

for i in range(0,G_00s_decade_5_95.size,5000):
    ax_1.scatter(G_00s_decade_5_95[i], awi_00s_decade_5_95[i], color='darkred', alpha=0.5)  
    
x = G_00s_decade_5_95[::5000]
y = awi_00s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell2 = EllipseModel()
ell2.estimate(a_points)

xc, yc, a, b, theta = ell2.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch2 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='darkred', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch2) 




    
    
G_90s_decade = np.mean(G_total[1990-1850:2001-1850,:], axis=0)
awi_90s_decade = np.mean(gwi_total[1990-1850:2001-1850,0,:], axis=0)

# print(G_90s_decade.size)
# print(awi_90s_decade.shape[0])

# for i in range(0,G_90s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_90s_decade[i])[::5], (awi_90s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='red')

G_90s_decade_all = np.zeros(awi_90s_decade.size)
for i in range(0,G_90s_decade.size):
    G_90s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_90s_decade[i]

G_90s_decade_5_95 = G_90s_decade_all[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]
awi_90s_decade_5_95 = awi_90s_decade[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]

for i in range(0,G_90s_decade_5_95.size,5000):
    ax_1.scatter(G_90s_decade_5_95[i], awi_90s_decade_5_95[i], color='red', alpha=0.5)  
    
x = G_90s_decade_5_95[::5000]
y = awi_90s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell3 = EllipseModel()
ell3.estimate(a_points)

xc, yc, a, b, theta = ell3.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch3 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='red', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch3) 




    
    
G_80s_decade = np.mean(G_total[1980-1850:1991-1850,:], axis=0)
awi_80s_decade = np.mean(gwi_total[1980-1850:1991-1850,0,:], axis=0)

# print(G_80s_decade.size)
# print(awi_80s_decade.shape[0])

# for i in range(0,G_80s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_80s_decade[i])[::5], (awi_80s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='coral')

G_80s_decade_all = np.zeros(awi_80s_decade.size)
for i in range(0,G_80s_decade.size):
    G_80s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_80s_decade[i]

G_80s_decade_5_95 = G_80s_decade_all[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]
awi_80s_decade_5_95 = awi_80s_decade[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]

for i in range(0,G_80s_decade_5_95.size,5000):
    ax_1.scatter(G_80s_decade_5_95[i], awi_80s_decade_5_95[i], color='coral', alpha=0.5)  

x = G_80s_decade_5_95[::5000]
y = awi_80s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell4 = EllipseModel()
ell4.estimate(a_points)

xc, yc, a, b, theta = ell4.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch4 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='coral', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch4)





G_70s_decade = np.mean(G_total[1970-1850:1981-1850,:], axis=0)
awi_70s_decade = np.mean(gwi_total[1970-1850:1981-1850,0,:], axis=0)

# print(G_70s_decade.size)
# print(awi_70s_decade.shape[0])

# for i in range(0,G_70s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

G_70s_decade_all = np.zeros(awi_70s_decade.size)
for i in range(0,G_70s_decade.size):
    G_70s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_70s_decade[i]

G_70s_decade_5_95 = G_70s_decade_all[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]
awi_70s_decade_5_95 = awi_70s_decade[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]

for i in range(0,G_70s_decade_5_95.size,5000):
    ax_1.scatter(G_70s_decade_5_95[i], awi_70s_decade_5_95[i], color='orange', alpha=0.5)  

x = G_70s_decade_5_95[::5000]
y = awi_70s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell5 = EllipseModel()
ell5.estimate(a_points)

xc, yc, a, b, theta = ell5.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch5 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='orange', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch5)
    
    
    
    
    
    
G_60s_decade = np.mean(G_total[1960-1850:1971-1850,:], axis=0)
awi_60s_decade = np.mean(gwi_total[1960-1850:1971-1850,0,:], axis=0)

# print(G_60s_decade.size)
# print(awi_60s_decade.shape[0])

# for i in range(0,G_70s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

G_60s_decade_all = np.zeros(awi_60s_decade.size)
for i in range(0,G_60s_decade.size):
    G_60s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_60s_decade[i]

G_60s_decade_5_95 = G_60s_decade_all[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]
awi_60s_decade_5_95 = awi_60s_decade[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]

for i in range(0,G_60s_decade_5_95.size,5000):
    ax_1.scatter(G_60s_decade_5_95[i], awi_60s_decade_5_95[i], color='gold', alpha=0.5)  
    
x = G_60s_decade_5_95[::5000]
y = awi_60s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell6 = EllipseModel()
ell6.estimate(a_points)

xc, yc, a, b, theta = ell6.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    

# using this exact set up on a and b to convert a 1 sigma ellipse on the points to a 5-95th percentile one!!!
ell_patch6 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='gold', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch6)    
    
    
    
    
    

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), [0,0], np.array([0,1200])*0.5*0.001, color='black', alpha=0.1, zorder=-1)
# # ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*0.89*0.001, color='black', alpha=0.1, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.5*0.001, np.array([0,1200])*1.0*0.001, color='black', alpha=0.15, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.0*0.001, np.array([0,1200])*1.5*0.001, color='black', alpha=0.2, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.5*0.001, np.array([0,1200])*2.0*0.001, color='black', alpha=0.25, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*2.0*0.001, np.array([0,1200])*2.5*0.001, color='black', alpha=0.3, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*2.5*0.001, np.array([0,1200])*3.0*0.001, color='black', alpha=0.35, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*3.0*0.001, np.array([0,1200])*3.5*0.001, color='black', alpha=0.4, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*3.5*0.001, np.array([0,1200])*4.0*0.001, color='black', alpha=0.45, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)


ax_1.fill_between(np.array([0,1200]), [0,0], np.array([0,1200])*0.15*44/12000, color='black', alpha=0.1, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.15*44/12000, np.array([0,1200])*0.30*44/12000, color='black', alpha=0.15, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.3*44/12000, np.array([0,1200])*0.45*44/12000, color='black', alpha=0.2, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.45*44/12000, np.array([0,1200])*0.6*44/12000, color='black', alpha=0.25, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.6*44/12000, np.array([0,1200])*0.75*44/12000, color='black', alpha=0.3, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.75*44/12000, np.array([0,1200])*0.9*44/12000, color='black', alpha=0.35, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.9*44/12000, np.array([0,1200])*1.05*44/12000, color='black', alpha=0.4, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.05*44/12000, np.array([0,1200])*10, color='black', alpha=0.45, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.69*0.001, np.array([0,1200])*2.04*0.001, color='black', alpha=0.5, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=0)

ax_1.plot(np.array([0,1200]), np.array([0,1200])*1.3*0.001, color='black', linewidth=5, zorder=10)
ax_1.plot(np.array([0,1200]), np.array([0,1200])*0.86*0.001, color='black', linewidth=3, zorder=0)
ax_1.plot(np.array([0,1200]), np.array([0,1200])*2.49*0.001, color='black', linewidth=3, zorder=0)

# ax_1.plot(np.array([0,1200]), np.array([0,1200])*0.89*0.001, color='white', zorder=0)

# ax_1.text(1100,1100*0.5*0.001,'0.14', fontsize=13, fontweight='bold')
# ax_1.text(1100,1100*1.0*0.001,'0.27', fontsize=13, fontweight='bold')
# ax_1.text(850,850*1.5*0.001 + 0.03,'0.41', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/2.0 - 15,850*1.5*0.001 + 0.03,'0.55', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 - 0.03)*1000/2.5 - 25,850*1.5*0.001 - 0.03,'0.68', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/3.0 - 25,850*1.5*0.001 + 0.03,'0.82', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 - 0.03)*1000/3.5 - 23,850*1.5*0.001 - 0.03,'0.95', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/4.0 - 30,850*1.5*0.001 + 0.03,'1.09', fontsize=13, fontweight='bold')

ax_1.text(1100,1100*0.15*44/12000 + 0.02,'0.15', fontsize=13, rotation=26, fontweight='bold')
ax_1.text(1100,1100*0.3*44/12000 + 0.03,'0.3', fontsize=13, rotation=40, fontweight='bold')
ax_1.text(820,1100*0.35*44/12000,'0.45', fontsize=13, rotation=50, fontweight='bold')
ax_1.text(620, 1100*0.35*44/12000,'0.6', fontsize=13, rotation=57, fontweight='bold')
ax_1.text(480, 1100*0.35*44/12000,'0.75', fontsize=13, rotation=65, fontweight='bold')
ax_1.text(410, 1100*0.35*44/12000,'0.9', fontsize=13, rotation=70, fontweight='bold')
ax_1.text(335, 1100*0.35*44/12000,'1.05', fontsize=13, rotation=72, fontweight='bold')



ax_1.set_xlim(0,1200)
# ax_1.set_xticklabels([0,str(np.round(0.2*44/12,2)),str(np.round(0.4*44/12,2)),str(np.round(0.6*44/12,2)),str(np.round(0.8*44/12,2)),str(np.round(1.0*44/12,2)),str(np.round(1.2*44/12,2))])
ax_1.set_xticks([0,12000/44,2*12000/44,3*12000/44,4*12000/44])
ax_1.set_xticklabels(['0','1.0','2.0','3.0','4.0'])
ax_1.set_ylim(0,1.5)
ax_1.set_xlabel('Cumulative emissions (TtCO$_2$-fe)', fontsize=14)
ax_1.set_ylabel('Temperature anomaly ($^{\circ}$C rel. to 1850-1900)', fontsize=14)
ax_1.tick_params(labelsize=14)

no_axes = ax_1.twiny()
no_axes.set_xticks([],[])
no_axes.set_xlabel('TCRE ($^{\circ}$C/TtCO$_2$)', fontsize=14)

ax_1.text(100*12/44, 1.36, 'a)', fontsize=14, fontweight='bold')


legend_elements = [Line2D([0], [0], marker='o', color='none', label='2009-2018',markerfacecolor='indianred', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='2000-2010',markerfacecolor='darkred', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1990-2000',markerfacecolor='red', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1980-1990',markerfacecolor='coral', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1970-1980',markerfacecolor='orange', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1960-1970',markerfacecolor='gold', markeredgecolor='none', markersize=8),]

ax_1.legend(handles=legend_elements, loc='lower right', edgecolor='none', framealpha=0.0, fontsize=12)

# TCRE range:
# 5th: 0.82
# 50th: 1.25
# 95th: 2.39
# mean = 1.37























# by scenario colour

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
co2_ems_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx', encoding='utf-8')
co2_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx', encoding='utf-8')
total_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc15_fair_magicc_temp_and_forcing.xlsx', encoding='utf-8')

# import RCP85 scenario to stitch onto past
RCP85_E = pd.read_csv('../RCP_data/RCP85_EMISSIONS.csv',skiprows=36,index_col=0)
RCP85_RF = pd.read_csv('../RCP_data/RCP85_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

# fig, ax = plt.subplots(2,2,figsize=(15,15))
# fig_peak, ax_peak = plt.subplots(figsize=(6,4.1))
# fig_2100, ax_2100 = plt.subplots(figsize=(6,6))

H = 100
alpha = 0.25
AGWP_CO2 = H/1200

colors = {'AIM/CGE 2.0':'red','AIM/CGE 2.1':'orange','C-ROADS-5.005':'gold','IMAGE 3.0.1':'lightgreen','MESSAGE V.3':'darkgreen','MESSAGE-GLOBIOM 1.0':'skyblue','REMIND 1.5':'darkblue','REMIND 1.7':'purple','REMIND-MAgPIE 1.7-3.0':'black'}

for val,i in enumerate(co2_ems_df.models()):
#     print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in co2_ems_df.filter(model=i).scenarios():
            print(i, j)
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='darkblue')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='darkblue')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='darkblue', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)


# ax_peak.set_xlim(-100,800)
# ax_peak.set_ylim(0,2000)
ax_peak.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=14)
ax_peak.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=14)
ax_peak.tick_params(labelsize=14)
ax_peak.tick_params(labelsize=14)

# ax_2100.set_xlim(0,230*44/12)
# ax_2100.set_ylim(-100*44/12,500*44/12)
# ax_2100.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=10)
# ax_2100.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=10)
# ax_2100.tick_params(labelsize=10)
# ax_2100.tick_params(labelsize=10)










two_lower_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx', encoding='utf-8')
two_lower_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx', encoding='utf-8')
two_lower_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2lower_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_lower_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_lower_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orange')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orange')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orange', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)











two_higher_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx', encoding='utf-8')
two_higher_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx', encoding='utf-8')
two_higher_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2higher_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_higher_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_higher_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orangered')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orangered')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orangered', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)
            
#             ax[1,1].plot(np.arange(2018,2101), non_co2_cum_actual, color='orangered')
#             ax[1,1].plot(np.arange(2018,2101), non_CO2_co2gwe_frompresent[2018-1765:], color='orangered', linestyle=':')



legend_elements = [Line2D([0], [0], marker='o', color='none', label='1.5$^{\circ}$C',markerfacecolor='darkblue', markeredgecolor='darkblue', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-lower',markerfacecolor='orange', markeredgecolor='orange', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-higher',markerfacecolor='orangered', markeredgecolor='orangered', markersize=7)]

ax_peak.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax_2100.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax[1,0].set_xlim(2018,2101)

ax_peak.set_xlim(0,1750)
ax_peak.set_ylim(0,1200)

# ax_2100.set_xlim(-300,1750)
# ax_2100.set_ylim(-300,1750)

ax_peak.annotate('0.22$^{\circ}$C/TtCO$_2$',xy=(1300,800),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak.annotate('0.45$^{\circ}$C/TtCO$_2$',xy=(250,800),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak.annotate('0.68$^{\circ}$C/TtCO$_2$',xy=(100,600),rotation=-45,color='black',fontsize=10, fontweight='bold')

CO2_budgets, nonCO2_co2fe_budgets = np.meshgrid(np.linspace(0.001,1000,100), np.linspace(0.001,1000,100))
TCREs = (1.5-1.1)*1000/((44/12)*(CO2_budgets + nonCO2_co2fe_budgets))
ax_peak.contourf(CO2_budgets*44/12, nonCO2_co2fe_budgets*44/12, TCREs, [0.22,0.45,0.68], cmap=plt.cm.Greys, alpha=0.7, linewidths=0.0, zorder=-100, extend='both')

ax_peak.plot([1140,0],[0,1140], color='black', linestyle='-', linewidth=2)
ax_peak.annotate('0.35$^{\circ}$C/TtCO$_2$',xy=(400,900),rotation=-45,color='black',fontsize=10, fontweight='bold')


ax_peak.text(50,1050, 'b)', fontsize=14, fontweight='bold')

ax_peak.set_xticks([0.0,500,1000,1500])
ax_peak.set_xticklabels(['0','0.5','1.0','1.5'])
ax_peak.set_yticks([0.0,500,1000])
ax_peak.set_yticklabels(['0','0.5','1.0'])
ax_peak.set_xlabel('Cumulative CO$_2$ emissions (TtCO$_2$)')
ax_peak.set_ylabel('')




# by scenario colour

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
co2_ems_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx', encoding='utf-8')
co2_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx', encoding='utf-8')
total_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc15_fair_magicc_temp_and_forcing.xlsx', encoding='utf-8')

# import RCP85 scenario to stitch onto past
RCP85_E = pd.read_csv('../RCP_data/RCP85_EMISSIONS.csv',skiprows=36,index_col=0)
RCP85_RF = pd.read_csv('../RCP_data/RCP85_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

# fig, ax = plt.subplots(2,2,figsize=(15,15))
# fig_peak2, ax_peak2 = plt.subplots(figsize=(6,4.1))
# fig_2100, ax_2100 = plt.subplots(figsize=(6,6))

H = 100
alpha = 0.25
AGWP_CO2 = H/1200

colors = {'AIM/CGE 2.0':'red','AIM/CGE 2.1':'orange','C-ROADS-5.005':'gold','IMAGE 3.0.1':'lightgreen','MESSAGE V.3':'darkgreen','MESSAGE-GLOBIOM 1.0':'skyblue','REMIND 1.5':'darkblue','REMIND 1.7':'purple','REMIND-MAgPIE 1.7-3.0':'black'}

for val,i in enumerate(co2_ems_df.models()):
#     print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in co2_ems_df.filter(model=i).scenarios():
            print(i, j)
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='darkblue')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='darkblue')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='darkblue', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)



# ax_peak.set_xlim(-100,800)
# ax_peak.set_ylim(0,2000)
ax_peak2.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=14)
ax_peak2.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=14)
ax_peak2.tick_params(labelsize=14)
ax_peak2.tick_params(labelsize=14)

# ax_2100.set_xlim(0,230*44/12)
# ax_2100.set_ylim(-100*44/12,500*44/12)
# ax_2100.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=10)
# ax_2100.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=10)
# ax_2100.tick_params(labelsize=10)
# ax_2100.tick_params(labelsize=10)










two_lower_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx', encoding='utf-8')
two_lower_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx', encoding='utf-8')
two_lower_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2lower_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_lower_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_lower_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orange')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orange')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orange', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)










two_higher_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx', encoding='utf-8')
two_higher_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx', encoding='utf-8')
two_higher_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2higher_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_higher_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_higher_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orangered')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orangered')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orangered', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)
            
#             ax[1,1].plot(np.arange(2018,2101), non_co2_cum_actual, color='orangered')
#             ax[1,1].plot(np.arange(2018,2101), non_CO2_co2gwe_frompresent[2018-1765:], color='orangered', linestyle=':')
            


legend_elements = [Line2D([0], [0], marker='o', color='none', label='1.5$^{\circ}$C',markerfacecolor='darkblue', markeredgecolor='darkblue', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-lower',markerfacecolor='orange', markeredgecolor='orange', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-higher',markerfacecolor='orangered', markeredgecolor='orangered', markersize=7)]

ax_peak2.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax_2100.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax[1,0].set_xlim(2018,2101)

ax_peak2.set_xlim(0,1750)
ax_peak2.set_ylim(0,1200)

# ax_2100.set_xlim(-300,1750)
# ax_2100.set_ylim(-300,1750)

ax_peak2.annotate('0.22$^{\circ}$C/TtCO$_2$',xy=(540,1050),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak2.annotate('0.45$^{\circ}$C/TtCO$_2$',xy=(80,700),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak2.annotate('0.68$^{\circ}$C/TtCO$_2$',xy=(10,490),rotation=-45,color='black',fontsize=10, fontweight='bold')

CO2_budgets, nonCO2_co2fe_budgets = np.meshgrid(np.linspace(0.001,1000,100), np.linspace(0.001,1000,100))
TCREs = (1.5-1.2)*1000/((44/12)*(CO2_budgets + nonCO2_co2fe_budgets))
ax_peak2.contourf(CO2_budgets*44/12, nonCO2_co2fe_budgets*44/12, TCREs, [0.22,0.45,0.68], cmap=plt.cm.Greys, alpha=0.7, linewidths=0.0, zorder=-100, extend='both')

ax_peak2.plot([750,0],[0,750], color='black', linestyle='-', linewidth=2)
ax_peak2.annotate('0.383$^{\circ}$C/TtCO$_2$',xy=(145,780),rotation=-45,color='black',fontsize=10, fontweight='bold')


ax_peak2.text(50,1050, 'c)', fontsize=14, fontweight='bold')

ax_peak2.set_xticks([0.0,500,1000,1500])
ax_peak2.set_xticklabels(['0','0.5','1.0','1.5'])
ax_peak2.set_yticks([0.0,500,1000])
ax_peak2.set_yticklabels(['0','0.5','1.0'])
ax_peak2.set_xlabel('Cumulative CO$_2$ emissions (TtCO$_2$)')
ax_peak2.set_ylabel('')



ax_peak2.text(-300,2400,'Cumulative non-CO$_2$ CO$_2$-fe emissions (TtCO$_2$)',rotation=90,fontsize=14)


# fig_peak2.savefig('scatter_non-CO2_co2fe_vs_co2_peakcumems_byscen_1p15.png', dpi=300)
# fig_2100.savefig('scatter_non-CO2_co2fe_vs_co2_2100_byscen.png', dpi=300)

# fig_peak.savefig('scatter_non-CO2_co2fe_vs_co2_peakcumems_byscen_1p05.png', dpi=300)
# fig_2100.savefig('scatter_non-CO2_co2fe_vs_co2_2100_byscen.png', dpi=300)

fig_1.savefig('2019_figure3_full.png', dpi=400)
# Out:
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# ...

# %%
# fig_1, ax_1 = plt.subplots(figsize=(10,10))
fig_1 = plt.figure(figsize=(5.5,12))
ax_1 = fig_1.add_axes([0.15,0.615,0.78,0.35])
ax_peak = fig_1.add_axes([0.15,0.33,0.78,0.23])
ax_peak2 = fig_1.add_axes([0.15,0.05,0.78,0.23])
ax_1.set_xlim(0,1200)
ax_1.set_ylim(0,1.4)

G_present_decade = np.mean(G_total[-10:,:], axis=0)
awi_present_decade = np.mean(gwi_total[-10:,0,:], axis=0)

# print(G_present_decade.size)
# print(awi_present_decade.shape[0])

G_present_decade_all = np.zeros(awi_present_decade.size)
for i in range(0,G_present_decade.size):
    G_present_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_present_decade[i]

G_present_decade_5_95 = G_present_decade_all[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]
awi_present_decade_5_95 = awi_present_decade[(G_present_decade_all < np.percentile(G_present_decade_all, 95))*(G_present_decade_all > np.percentile(G_present_decade_all, 5)) * (awi_present_decade < np.percentile(awi_present_decade, 95))*(awi_present_decade > np.percentile(awi_present_decade, 5))]

# for i in range(0,G_present_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_present_decade[i])[::5], (awi_present_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='darkred')
    
for i in range(0,G_present_decade_5_95.size,5000):
    ax_1.scatter(G_present_decade_5_95[i], awi_present_decade_5_95[i], color='indianred', alpha=0.5)

    
x = G_present_decade_5_95[::5000]
y = awi_present_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell = EllipseModel()
ell.estimate(a_points)

xc, yc, a, b, theta = ell.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='indianred', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch)   
    
    
    
    
    
    
G_00s_decade = np.mean(G_total[2000-1850:2011-1850,:], axis=0)
awi_00s_decade = np.mean(gwi_total[2000-1850:2011-1850,0,:], axis=0)

# print(G_00s_decade.size)
# print(awi_00s_decade.shape[0])

# for i in range(0,G_00s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_00s_decade[i])[::5], (awi_00s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='indianred')

G_00s_decade_all = np.zeros(awi_00s_decade.size)
for i in range(0,G_00s_decade.size):
    G_00s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_00s_decade[i]

G_00s_decade_5_95 = G_00s_decade_all[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]
awi_00s_decade_5_95 = awi_00s_decade[(G_00s_decade_all < np.percentile(G_00s_decade_all, 95))*(G_00s_decade_all > np.percentile(G_00s_decade_all, 5)) * (awi_00s_decade < np.percentile(awi_00s_decade, 95))*(awi_00s_decade > np.percentile(awi_00s_decade, 5))]

for i in range(0,G_00s_decade_5_95.size,5000):
    ax_1.scatter(G_00s_decade_5_95[i], awi_00s_decade_5_95[i], color='darkred', alpha=0.5)  
    
x = G_00s_decade_5_95[::5000]
y = awi_00s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell2 = EllipseModel()
ell2.estimate(a_points)

xc, yc, a, b, theta = ell2.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch2 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='darkred', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch2) 




    
    
G_90s_decade = np.mean(G_total[1990-1850:2001-1850,:], axis=0)
awi_90s_decade = np.mean(gwi_total[1990-1850:2001-1850,0,:], axis=0)

# print(G_90s_decade.size)
# print(awi_90s_decade.shape[0])

# for i in range(0,G_90s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_90s_decade[i])[::5], (awi_90s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='red')

G_90s_decade_all = np.zeros(awi_90s_decade.size)
for i in range(0,G_90s_decade.size):
    G_90s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_90s_decade[i]

G_90s_decade_5_95 = G_90s_decade_all[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]
awi_90s_decade_5_95 = awi_90s_decade[(G_90s_decade_all < np.percentile(G_90s_decade_all, 95))*(G_90s_decade_all > np.percentile(G_90s_decade_all, 5)) * (awi_90s_decade < np.percentile(awi_90s_decade, 95))*(awi_90s_decade > np.percentile(awi_90s_decade, 5))]

for i in range(0,G_90s_decade_5_95.size,5000):
    ax_1.scatter(G_90s_decade_5_95[i], awi_90s_decade_5_95[i], color='red', alpha=0.5)  
    
x = G_90s_decade_5_95[::5000]
y = awi_90s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell3 = EllipseModel()
ell3.estimate(a_points)

xc, yc, a, b, theta = ell3.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch3 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='red', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch3) 




    
    
G_80s_decade = np.mean(G_total[1980-1850:1991-1850,:], axis=0)
awi_80s_decade = np.mean(gwi_total[1980-1850:1991-1850,0,:], axis=0)

# print(G_80s_decade.size)
# print(awi_80s_decade.shape[0])

# for i in range(0,G_80s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_80s_decade[i])[::5], (awi_80s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='coral')

G_80s_decade_all = np.zeros(awi_80s_decade.size)
for i in range(0,G_80s_decade.size):
    G_80s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_80s_decade[i]

G_80s_decade_5_95 = G_80s_decade_all[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]
awi_80s_decade_5_95 = awi_80s_decade[(G_80s_decade_all < np.percentile(G_80s_decade_all, 95))*(G_80s_decade_all > np.percentile(G_80s_decade_all, 5)) * (awi_80s_decade < np.percentile(awi_80s_decade, 95))*(awi_80s_decade > np.percentile(awi_80s_decade, 5))]

for i in range(0,G_80s_decade_5_95.size,5000):
    ax_1.scatter(G_80s_decade_5_95[i], awi_80s_decade_5_95[i], color='coral', alpha=0.5)  

x = G_80s_decade_5_95[::5000]
y = awi_80s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell4 = EllipseModel()
ell4.estimate(a_points)

xc, yc, a, b, theta = ell4.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch4 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='coral', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch4)





G_70s_decade = np.mean(G_total[1970-1850:1981-1850,:], axis=0)
awi_70s_decade = np.mean(gwi_total[1970-1850:1981-1850,0,:], axis=0)

# print(G_70s_decade.size)
# print(awi_70s_decade.shape[0])

# for i in range(0,G_70s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

G_70s_decade_all = np.zeros(awi_70s_decade.size)
for i in range(0,G_70s_decade.size):
    G_70s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_70s_decade[i]

G_70s_decade_5_95 = G_70s_decade_all[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]
awi_70s_decade_5_95 = awi_70s_decade[(G_70s_decade_all < np.percentile(G_70s_decade_all, 95))*(G_70s_decade_all > np.percentile(G_70s_decade_all, 5)) * (awi_70s_decade < np.percentile(awi_70s_decade, 95))*(awi_70s_decade > np.percentile(awi_70s_decade, 5))]

for i in range(0,G_70s_decade_5_95.size,5000):
    ax_1.scatter(G_70s_decade_5_95[i], awi_70s_decade_5_95[i], color='orange', alpha=0.5)  

x = G_70s_decade_5_95[::5000]
y = awi_70s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell5 = EllipseModel()
ell5.estimate(a_points)

xc, yc, a, b, theta = ell5.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    
ell_patch5 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='orange', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch5)
    
    
    
    
    
    
G_60s_decade = np.mean(G_total[1960-1850:1971-1850,:], axis=0)
awi_60s_decade = np.mean(gwi_total[1960-1850:1971-1850,0,:], axis=0)

# print(G_60s_decade.size)
# print(awi_60s_decade.shape[0])

# for i in range(0,G_70s_decade.size,250):
#     ax_1.scatter((np.ones(conditions_total[i])*G_70s_decade[i])[::5], (awi_70s_decade[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])])[::5], color='orange')

G_60s_decade_all = np.zeros(awi_60s_decade.size)
for i in range(0,G_60s_decade.size):
    G_60s_decade_all[np.sum(conditions_total[:i]):np.sum(conditions_total[:i+1])] = np.ones(conditions_total[i])*G_60s_decade[i]

G_60s_decade_5_95 = G_60s_decade_all[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]
awi_60s_decade_5_95 = awi_60s_decade[(G_60s_decade_all < np.percentile(G_60s_decade_all, 95))*(G_60s_decade_all > np.percentile(G_60s_decade_all, 5)) * (awi_60s_decade < np.percentile(awi_60s_decade, 95))*(awi_60s_decade > np.percentile(awi_60s_decade, 5))]

for i in range(0,G_60s_decade_5_95.size,5000):
    ax_1.scatter(G_60s_decade_5_95[i], awi_60s_decade_5_95[i], color='gold', alpha=0.5)  
    
x = G_60s_decade_5_95[::5000]
y = awi_60s_decade_5_95[::5000]
a_points = np.zeros((x.size,2))
a_points[:,0] = x
a_points[:,1] = y

ell6 = EllipseModel()
ell6.estimate(a_points)

xc, yc, a, b, theta = ell6.params

print("center = ",  (xc, yc))
print("angle of rotation = ",  theta)
print("axes = ", (a,b))  
    
# ax_1.scatter(xc, yc, color='blue', s=100)    

# using this exact set up on a and b to convert a 1 sigma ellipse on the points to a 5-95th percentile one!!!
ell_patch6 = Ellipse((xc, yc), 2*np.sqrt(5.991*a**2/2.16), 2*np.sqrt(5.991*b**2/2.16), theta*180/np.pi, edgecolor='gold', facecolor='none', zorder=10, linewidth=3)
ax_1.add_patch(ell_patch6)    
    
    
    
    
    

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), [0,0], np.array([0,1200])*0.5*0.001, color='black', alpha=0.1, zorder=-1)
# # ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*0.89*0.001, color='black', alpha=0.1, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.5*0.001, np.array([0,1200])*1.0*0.001, color='black', alpha=0.15, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.0*0.001, np.array([0,1200])*1.5*0.001, color='black', alpha=0.2, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.5*0.001, np.array([0,1200])*2.0*0.001, color='black', alpha=0.25, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*2.0*0.001, np.array([0,1200])*2.5*0.001, color='black', alpha=0.3, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*2.5*0.001, np.array([0,1200])*3.0*0.001, color='black', alpha=0.35, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*3.0*0.001, np.array([0,1200])*3.5*0.001, color='black', alpha=0.4, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*3.5*0.001, np.array([0,1200])*4.0*0.001, color='black', alpha=0.45, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)


ax_1.fill_between(np.array([0,1200]), [0,0], np.array([0,1200])*0.15*44/12000, color='black', alpha=0.1, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.15*44/12000, np.array([0,1200])*0.30*44/12000, color='black', alpha=0.15, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.3*44/12000, np.array([0,1200])*0.45*44/12000, color='black', alpha=0.2, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.45*44/12000, np.array([0,1200])*0.6*44/12000, color='black', alpha=0.25, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.6*44/12000, np.array([0,1200])*0.75*44/12000, color='black', alpha=0.3, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.75*44/12000, np.array([0,1200])*0.9*44/12000, color='black', alpha=0.35, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.9*44/12000, np.array([0,1200])*1.05*44/12000, color='black', alpha=0.4, zorder=-1)
ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.05*44/12000, np.array([0,1200])*10, color='black', alpha=0.45, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*1.69*0.001, np.array([0,1200])*2.04*0.001, color='black', alpha=0.5, zorder=-1)
# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*4.0*0.001, np.array([0,1200])*10, color='black', alpha=0.5, zorder=-1)

# ax_1.fill_between(np.array([0,1200]), np.array([0,1200])*0.82*0.001, np.array([0,1200])*2.39*0.001, color='black', alpha=0.6, zorder=0)

ax_1.plot(np.array([0,1200]), np.array([0,1200])*1.3*0.001, color='black', linewidth=5, zorder=10)
ax_1.plot(np.array([0,1200]), np.array([0,1200])*0.85*0.001, color='black', linewidth=3, zorder=0)
ax_1.plot(np.array([0,1200]), np.array([0,1200])*2.49*0.001, color='black', linewidth=3, zorder=0)

# ax_1.plot(np.array([0,1200]), np.array([0,1200])*0.89*0.001, color='white', zorder=0)

# ax_1.text(1100,1100*0.5*0.001,'0.14', fontsize=13, fontweight='bold')
# ax_1.text(1100,1100*1.0*0.001,'0.27', fontsize=13, fontweight='bold')
# ax_1.text(850,850*1.5*0.001 + 0.03,'0.41', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/2.0 - 15,850*1.5*0.001 + 0.03,'0.55', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 - 0.03)*1000/2.5 - 25,850*1.5*0.001 - 0.03,'0.68', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/3.0 - 25,850*1.5*0.001 + 0.03,'0.82', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 - 0.03)*1000/3.5 - 23,850*1.5*0.001 - 0.03,'0.95', fontsize=13, fontweight='bold')
# ax_1.text((850*1.5*0.001 + 0.03)*1000/4.0 - 30,850*1.5*0.001 + 0.03,'1.09', fontsize=13, fontweight='bold')

ax_1.text(1100,1100*0.15*44/12000 + 0.03,'0.15', fontsize=10, rotation=26, fontweight='bold')
ax_1.text(1100,1100*0.3*44/12000 + 0.03,'0.3', fontsize=10, rotation=40, fontweight='bold')
ax_1.text(820,1100*0.35*44/12000,'0.45', fontsize=10, rotation=50, fontweight='bold')
ax_1.text(620, 1100*0.35*44/12000,'0.6', fontsize=10, rotation=57, fontweight='bold')
ax_1.text(480, 1100*0.35*44/12000,'0.75', fontsize=10, rotation=65, fontweight='bold')
ax_1.text(410, 1100*0.35*44/12000,'0.9', fontsize=10, rotation=70, fontweight='bold')
ax_1.text(335, 1100*0.35*44/12000,'1.05', fontsize=10, rotation=72, fontweight='bold')



ax_1.set_xlim(0,1200)
# ax_1.set_xticklabels([0,str(np.round(0.2*44/12,2)),str(np.round(0.4*44/12,2)),str(np.round(0.6*44/12,2)),str(np.round(0.8*44/12,2)),str(np.round(1.0*44/12,2)),str(np.round(1.2*44/12,2))])
ax_1.set_xticks([0,12000/44,2*12000/44,3*12000/44,4*12000/44])
ax_1.set_xticklabels(['0','1.0','2.0','3.0','4.0'])
ax_1.set_ylim(0,1.5)
ax_1.set_xlabel('Cumulative emissions (TtCO$_2$-fe)', fontsize=14)
ax_1.set_ylabel('Temperature anomaly ($^{\circ}$C rel. to 1850-1900)', fontsize=14)
ax_1.tick_params(labelsize=14)

no_axes = ax_1.twiny()
no_axes.set_xticks([],[])
no_axes.set_xlabel('TCRE ($^{\circ}$C/TtCO$_2$)', fontsize=14)

ax_1.text(100*12/44, 1.36, 'a)', fontsize=14, fontweight='bold')


legend_elements = [Line2D([0], [0], marker='o', color='none', label='2009-2018',markerfacecolor='indianred', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='2000-2010',markerfacecolor='darkred', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1990-2000',markerfacecolor='red', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1980-1990',markerfacecolor='coral', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1970-1980',markerfacecolor='orange', markeredgecolor='none', markersize=8),
                  Line2D([0], [0], marker='o', color='none', label='1960-1970',markerfacecolor='gold', markeredgecolor='none', markersize=8),]

ax_1.legend(handles=legend_elements, loc='lower right', edgecolor='none', framealpha=0.0, fontsize=12)

# TCRE range:
# 5th: 0.86
# 50th: 1.30
# 95th: 2.49
# mean = 1.43























# by scenario colour

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
co2_ems_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx', encoding='utf-8')
co2_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx', encoding='utf-8')
total_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc15_fair_magicc_temp_and_forcing.xlsx', encoding='utf-8')

# import RCP85 scenario to stitch onto past
RCP85_E = pd.read_csv('../RCP_data/RCP85_EMISSIONS.csv',skiprows=36,index_col=0)
RCP85_RF = pd.read_csv('../RCP_data/RCP85_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

# fig, ax = plt.subplots(2,2,figsize=(15,15))
# fig_peak, ax_peak = plt.subplots(figsize=(6,4.1))
# fig_2100, ax_2100 = plt.subplots(figsize=(6,6))

H = 100
alpha = 0.25
AGWP_CO2 = H/1200

colors = {'AIM/CGE 2.0':'red','AIM/CGE 2.1':'orange','C-ROADS-5.005':'gold','IMAGE 3.0.1':'lightgreen','MESSAGE V.3':'darkgreen','MESSAGE-GLOBIOM 1.0':'skyblue','REMIND 1.5':'darkblue','REMIND 1.7':'purple','REMIND-MAgPIE 1.7-3.0':'black'}

for val,i in enumerate(co2_ems_df.models()):
#     print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in co2_ems_df.filter(model=i).scenarios():
            print(i, j)
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='darkblue')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='darkblue')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='darkblue', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)


# ax_peak.set_xlim(-100,800)
# ax_peak.set_ylim(0,2000)
ax_peak.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=14)
ax_peak.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=14)
ax_peak.tick_params(labelsize=14)
ax_peak.tick_params(labelsize=14)

# ax_2100.set_xlim(0,230*44/12)
# ax_2100.set_ylim(-100*44/12,500*44/12)
# ax_2100.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=10)
# ax_2100.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=10)
# ax_2100.tick_params(labelsize=10)
# ax_2100.tick_params(labelsize=10)










two_lower_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx', encoding='utf-8')
two_lower_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx', encoding='utf-8')
two_lower_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2lower_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_lower_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_lower_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orange')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orange')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orange', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)











two_higher_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx', encoding='utf-8')
two_higher_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx', encoding='utf-8')
two_higher_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2higher_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_higher_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_higher_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orangered')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orangered')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orangered', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)
            
#             ax[1,1].plot(np.arange(2018,2101), non_co2_cum_actual, color='orangered')
#             ax[1,1].plot(np.arange(2018,2101), non_CO2_co2gwe_frompresent[2018-1765:], color='orangered', linestyle=':')



legend_elements = [Line2D([0], [0], marker='o', color='none', label='1.5$^{\circ}$C',markerfacecolor='darkblue', markeredgecolor='darkblue', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-lower',markerfacecolor='orange', markeredgecolor='orange', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-higher',markerfacecolor='orangered', markeredgecolor='orangered', markersize=7)]

ax_peak.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax_2100.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax[1,0].set_xlim(2018,2101)

ax_peak.set_xlim(0,1750)
ax_peak.set_ylim(0,1200)

# ax_2100.set_xlim(-300,1750)
# ax_2100.set_ylim(-300,1750)

ax_peak.annotate('0.22$^{\circ}$C/TtCO$_2$',xy=(1300,530),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak.annotate('0.45$^{\circ}$C/TtCO$_2$',xy=(100,800),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak.annotate('0.68$^{\circ}$C/TtCO$_2$',xy=(50,530),rotation=-45,color='black',fontsize=10, fontweight='bold')

CO2_budgets, nonCO2_co2fe_budgets = np.meshgrid(np.linspace(0.001,1000,100), np.linspace(0.001,1000,100))
TCREs = (1.5-1.1)*1000/((44/12)*(CO2_budgets + nonCO2_co2fe_budgets))
ax_peak.contourf(CO2_budgets*44/12, nonCO2_co2fe_budgets*44/12, TCREs, [0.22,0.45,0.68], cmap=plt.cm.Greys, alpha=0.7, linewidths=0.0, zorder=-100, extend='both')

ax_peak.plot([1140,0],[0,1140], color='black', linestyle='-', linewidth=2)
ax_peak.annotate('0.35$^{\circ}$C/TtCO$_2$',xy=(275,900),rotation=-45,color='black',fontsize=10, fontweight='bold')


ax_peak.text(50,1050, 'b)', fontsize=14, fontweight='bold')

ax_peak.set_xticks([0.0,500,1000,1500])
ax_peak.set_xticklabels(['0','0.5','1.0','1.5'])
ax_peak.set_yticks([0.0,500,1000])
ax_peak.set_yticklabels(['0','0.5','1.0'])
ax_peak.set_xlabel('Cumulative CO$_2$ emissions (TtCO$_2$)')
ax_peak.set_ylabel('')




# by scenario colour

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
co2_ems_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx', encoding='utf-8')
co2_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx', encoding='utf-8')
total_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc15_fair_magicc_temp_and_forcing.xlsx', encoding='utf-8')

# import RCP85 scenario to stitch onto past
RCP85_E = pd.read_csv('../RCP_data/RCP85_EMISSIONS.csv',skiprows=36,index_col=0)
RCP85_RF = pd.read_csv('../RCP_data/RCP85_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

# fig, ax = plt.subplots(2,2,figsize=(15,15))
# fig_peak2, ax_peak2 = plt.subplots(figsize=(6,4.1))
# fig_2100, ax_2100 = plt.subplots(figsize=(6,6))

H = 100
alpha = 0.25
AGWP_CO2 = H/1200

colors = {'AIM/CGE 2.0':'red','AIM/CGE 2.1':'orange','C-ROADS-5.005':'gold','IMAGE 3.0.1':'lightgreen','MESSAGE V.3':'darkgreen','MESSAGE-GLOBIOM 1.0':'skyblue','REMIND 1.5':'darkblue','REMIND 1.7':'purple','REMIND-MAgPIE 1.7-3.0':'black'}

for val,i in enumerate(co2_ems_df.models()):
#     print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in co2_ems_df.filter(model=i).scenarios():
            print(i, j)
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='darkblue')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='darkblue')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='darkblue', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)

#             print(non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12)
        


# ax_peak.set_xlim(-100,800)
# ax_peak.set_ylim(0,2000)
ax_peak2.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=14)
ax_peak2.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=14)
ax_peak2.tick_params(labelsize=14)
ax_peak2.tick_params(labelsize=14)

# ax_2100.set_xlim(0,230*44/12)
# ax_2100.set_ylim(-100*44/12,500*44/12)
# ax_2100.set_ylabel('Cumulative Non-CO$_2$ CO$_2$-fe emissions (GtCO$_2$)', fontsize=10)
# ax_2100.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=10)
# ax_2100.tick_params(labelsize=10)
# ax_2100.tick_params(labelsize=10)










two_lower_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx', encoding='utf-8')
two_lower_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx', encoding='utf-8')
two_lower_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2lower_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_lower_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_lower_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_lower_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orange')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orange')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orange', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)

#             print(non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12)








two_higher_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx', encoding='utf-8')
two_higher_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx', encoding='utf-8')
two_higher_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx', encoding='utf-8')

MAGICC_forcing = pyam.IamDataFrame(data='./data/iamc2higher_magicc_temp_and_forcing.xlsx', encoding='utf-8')

for val,i in enumerate(two_higher_co2_ems_df.models()):
    print(i)
    if i in list(MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED').models().values):       

        for j in two_higher_co2_ems_df.filter(model=i).scenarios():
            co2_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|CO2|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            total_rf = MAGICC_forcing.filter(variable='AR5 climate diagnostics|Forcing|MAGICC6|MED', model=i, scenario=j).as_pandas().value.values
            
            non_co2_rf = total_rf - co2_rf
            
            co2_ems = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).interpolate().value.values
            co2_ems_years = two_higher_co2_ems_df.filter(model=i, scenario=j, variable='Emissions|CO2').as_pandas().set_index('year').reindex(np.arange(2005,2101)).index.values
            
            
#             ax[0,0].plot(np.arange(2000,2101), total_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), co2_rf, color=colors[i])
#             ax[0,0].plot(np.arange(2000,2101), non_co2_rf, color=colors[i])
            
#             ax[0,1].plot(co2_ems_years, co2_ems*12/44000, color=colors[i])
            
            
            non_co2_rf_plushist = np.zeros(2101-1765)
            non_co2_rf_plushist[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            
            non_co2_rf_plushist_plusfut = np.zeros(2111-1765)
            non_co2_rf_plushist_plusfut[2000-1765:2101-1765] = non_co2_rf
            non_co2_rf_plushist_plusfut[:2000-1765] = RCP85_RF['TOTAL_ANTHRO_RF'].loc[:1999] * non_co2_rf[0]/RCP85_RF['TOTAL_ANTHRO_RF'].loc[2000]
            non_co2_rf_plushist_plusfut[2101-1765:] = non_co2_rf[-1] + (non_co2_rf[-1] - non_co2_rf[-2])*np.arange(1,11)
            
            E_back = fair_scm_emsback(non_co2_rf_plushist_plusfut, TCR=1.6, ECS=2.75)[1]
            non_co2_cum_actual = np.cumsum(E_back[2018-1765:2101-1765])
            
            total_cum_ems_actual = non_co2_cum_actual + np.cumsum(co2_ems[2018-2005:]*12/44000)
            ax_peak2.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[np.argmax(total_cum_ems_actual)], non_co2_cum_actual[np.argmax(total_cum_ems_actual)]*44/12, color='orangered')
#             ax_2100.scatter(np.cumsum(co2_ems[2018-2005:]/1000)[-1], non_co2_cum_actual[-1]*44/12, color='orangered')
            
            non_CO2_co2gwe_frompresent = np.zeros(2101-1765)
            for k in range(2018-1765,2101-1765):
                offsets = (12/44)*H*(1-alpha)*(alpha*np.sum(non_co2_rf_plushist[2018-1765:k-20])/(H*(1-alpha)))/AGWP_CO2
    
                non_CO2_co2gwe_frompresent[k] = (12/44)*H*(1-alpha)*(non_co2_rf_plushist[k] - non_co2_rf_plushist[2018-1765] + alpha*np.mean(non_co2_rf_plushist[k-20:k+1])*(20)/(H*(1-alpha)))/AGWP_CO2 + offsets

#             ax[1,0].plot(np.arange(1765,2101), non_CO2_co2gwe_frompresent, color='orangered', linestyle='--', label='Stu Formula from present_new3')

            total_cum_ems_new = non_CO2_co2gwe_frompresent[2018-1765:] + np.cumsum(co2_ems[2018-2005:]*12/44000)
            
#             ax[1,1].plot(np.arange(2018,2101), non_co2_cum_actual, color='orangered')
#             ax[1,1].plot(np.arange(2018,2101), non_CO2_co2gwe_frompresent[2018-1765:], color='orangered', linestyle=':')
            


legend_elements = [Line2D([0], [0], marker='o', color='none', label='1.5$^{\circ}$C',markerfacecolor='darkblue', markeredgecolor='darkblue', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-lower',markerfacecolor='orange', markeredgecolor='orange', markersize=7),
                  Line2D([0], [0], marker='o', color='none', label='2$^{\circ}$C-higher',markerfacecolor='orangered', markeredgecolor='orangered', markersize=7)]

ax_peak2.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax_2100.legend(handles=legend_elements, loc='best', edgecolor='none', framealpha=0.0, fontsize=10)

# ax[1,0].set_xlim(2018,2101)

ax_peak2.set_xlim(0,1750)
ax_peak2.set_ylim(0,1200)

# ax_2100.set_xlim(-300,1750)
# ax_2100.set_ylim(-300,1750)

ax_peak2.annotate('0.22$^{\circ}$C/TtCO$_2$',xy=(500,900),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak2.annotate('0.45$^{\circ}$C/TtCO$_2$',xy=(15,530),rotation=-45,color='black',fontsize=10, fontweight='bold')
ax_peak2.annotate('0.68$^{\circ}$C/TtCO$_2$',xy=(10,290),rotation=-45,color='black',fontsize=10, fontweight='bold')

CO2_budgets, nonCO2_co2fe_budgets = np.meshgrid(np.linspace(0.001,1000,100), np.linspace(0.001,1000,100))
TCREs = (1.5-1.2)*1000/((44/12)*(CO2_budgets + nonCO2_co2fe_budgets))
ax_peak2.contourf(CO2_budgets*44/12, nonCO2_co2fe_budgets*44/12, TCREs, [0.22,0.45,0.68], cmap=plt.cm.Greys, alpha=0.7, linewidths=0.0, zorder=-100, extend='both')

ax_peak2.plot([750,0],[0,750], color='black', linestyle='-', linewidth=2)
ax_peak2.annotate('0.40$^{\circ}$C/TtCO$_2$',xy=(80,700),rotation=-45,color='black',fontsize=10, fontweight='bold')


ax_peak2.text(50,1050, 'c)', fontsize=14, fontweight='bold')

ax_peak2.set_xticks([0.0,500,1000,1500])
ax_peak2.set_xticklabels(['0','0.5','1.0','1.5'])
ax_peak2.set_yticks([0.0,500,1000])
ax_peak2.set_yticklabels(['0','0.5','1.0'])
ax_peak2.set_xlabel('Cumulative CO$_2$ emissions (TtCO$_2$)')
ax_peak2.set_ylabel('')



ax_peak2.text(-250,2200,'Cumulative non-CO$_2$ CO$_2$-fe emissions (TtCO$_2$)',rotation=90,fontsize=14)


# fig_peak2.savefig('scatter_non-CO2_co2fe_vs_co2_peakcumems_byscen_1p15.png', dpi=300)
# fig_2100.savefig('scatter_non-CO2_co2fe_vs_co2_2100_byscen.png', dpi=300)

# fig_peak.savefig('scatter_non-CO2_co2fe_vs_co2_peakcumems_byscen_1p05.png', dpi=300)
# fig_2100.savefig('scatter_non-CO2_co2fe_vs_co2_2100_byscen.png', dpi=300)

# fig_1.savefig('2019_figure3_full_vert.png', dpi=400)
# Out:
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# ...

# %%
# non_co2_budgets_15_2lower = np.array([162.78,247.07,252.57,262.01,219.63,208.73,223.56,207.74,279.22,230.13,248.35,268.55,215.28,238.91,238.60,270.98,214.20,255.68,268.07,351.41,349.53,351.21,356.40,269.45,272.68,255.13,350.21,256.55,317.23,322.74,241.87,205.02,138.43,180.25,157.80,182.19,136.39,182.94,214.10,137.46,343.38,339.27,70.96,35.34,28.33,54.29,65.09,62.07,53.85,51.11,49.73,68.53,32.86,348.31,371.38,239.47,314.04,460.22,586.25,415.68,440.09,537.91,195.28,241.47,251.57,231.24,225.10,307.64,339.05,234.28,307.33,311.03,213.32,167.72])
# non_co2_budgets_15 = np.array([162.78,247.07,252.57,262.01,219.63,208.73,223.56,207.74,279.22,230.13,248.35,268.55,215.28,238.91,238.60,270.98,214.20,255.68,268.07,351.41,349.53,351.21,356.40,269.45,272.68,255.13,350.21,256.55,317.23,322.74,241.87,205.02,138.43,180.25,157.80,182.19,136.39,182.94,214.10])

# print(np.percentile(non_co2_budgets_15_2lower, 50))
# print(np.min(non_co2_budgets_15_2lower))
# print(np.max(non_co2_budgets_15_2lower))

# print(np.percentile(non_co2_budgets_15, 50))
# print(np.min(non_co2_budgets_15))
# print(np.max(non_co2_budgets_15))
# Out:
# 240.47
# 28.33
# 586.25
# 247.07
# 136.39
# 356.4

# %%
test = np.random.lognormal(0.346,0.597,100000)

h = plt.hist(test, bins = 1000)

# print(np.percentile(test, 17))
# print(np.percentile(test, 83))


print(np.percentile(test, 10)*12/44)
print(np.percentile(test, 20)*12/44)
print(np.percentile(test, 30)*12/44)
print(np.percentile(test, 40)*12/44)
print(np.percentile(test, 50)*12/44)
print(np.percentile(test, 60)*12/44)
print(np.percentile(test, 70)*12/44)
print(np.percentile(test, 80)*12/44)
print(np.percentile(test, 90)*12/44)
# Out:
# 0.1793163375559512
# 0.23364568820528978
# 0.2823968656928638
# 0.33258301650854144
# 0.3871059643398271
# 0.45039971512930244
# 0.5295251005812077
# 0.6395687722076178
# 0.8323533843876134

# %%
test = np.random.normal((0.8+2.5)/2,0.885,100000)

h = plt.hist(test, bins = 1000)

# print(np.percentile(test, 17))
# print(np.percentile(test, 83))


print(np.percentile(test, 10)*12/44)
print(np.percentile(test, 20)*12/44)
print(np.percentile(test, 30)*12/44)
print(np.percentile(test, 40)*12/44)
print(np.percentile(test, 50)*12/44)
print(np.percentile(test, 60)*12/44)
print(np.percentile(test, 70)*12/44)
print(np.percentile(test, 80)*12/44)
print(np.percentile(test, 90)*12/44)
# Out:
# 0.13987126254339063
# 0.2448137234931041
# 0.3215850817263945
# 0.3870722864172946
# 0.44907165394386594
# 0.510608868802713
# 0.5758273184695725
# 0.6520433356475418
# 0.7581638203476289
