# %%
import numpy as np
import scipy as sp
import matplotlib
from matplotlib import pyplot as plt
import pyam
import pandas as pd
import sys
sys.path.append('/Users/stuartjenkins/Documents/$$Work/2019:02:01 - Carbon budgets with CO2-fe paper')
from fair_scm import *


# from scipy.stats import lognorm
# from scipy import stats
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

from scipy.ndimage.filters import gaussian_filter

from scipy.optimize import curve_fit

# %%
# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
co2_ems_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx', encoding='utf-8')
co2_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx', encoding='utf-8')
total_RF_df = pyam.IamDataFrame(data='../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx', encoding='utf-8')

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
two_lower_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx', encoding='utf-8')
two_lower_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx', encoding='utf-8')
two_lower_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx', encoding='utf-8')

# import the datasets from subfolder "15_degree_compatible_scens_IIASA"
two_higher_co2_ems_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx', encoding='utf-8')
two_higher_co2_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx', encoding='utf-8')
two_higher_total_RF_df = pyam.IamDataFrame(data='../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx', encoding='utf-8')

# import RCP85 scenario to stitch onto past
RCP85_E = pd.read_csv('../RCP_data/RCP85_EMISSIONS.csv',skiprows=36,index_col=0)
RCP85_RF = pd.read_csv('../RCP_data/RCP85_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

RCP3_E = pd.read_csv('../RCP_data/RCP3PD_EMISSIONS.csv',skiprows=36,index_col=0)
RCP3_RF = pd.read_csv('../RCP_data/RCP3PD_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

RCP45_E = pd.read_csv('../RCP_data/RCP45_EMISSIONS.csv',skiprows=36,index_col=0)
RCP45_RF = pd.read_csv('../RCP_data/RCP45_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

RCP6_E = pd.read_csv('../RCP_data/RCP6_EMISSIONS.csv',skiprows=36,index_col=0)
RCP6_RF = pd.read_csv('../RCP_data/RCP6_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)
# Out:
# INFO:root:Reading `../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2ems.xlsx`
# INFO:root:Reading `../15_degree_compatible_scens_IIASA/iamc15_snapshot_co2rf.xlsx`
# INFO:root:Reading `../15_degree_compatible_scens_IIASA/iamc15_snapshot_totalrf.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_co2_ems_2lower.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_co2_forcing_2lower.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_total_forcing_2lower.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_co2_ems_2higher.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_co2_forcing_2higher.xlsx`
# INFO:root:Reading `../2degree_IIASA_scenarios/iamc15_total_forcing_2higher.xlsx`

# %%
# what is the year we run the comparison from (chosen because we need 20 years of non-CO2 forcing data find F_0)
year_val = 2018
non_co2_forcing_average_over = 10

fbar_s = np.array([])
f0_s = np.array([])
f1_s = np.array([])
delta_fs = np.array([])

# Parameter values
full_index = np.arange(1765,2101)
TCR_val = 1.6
ECS_val = 2.75
d_array = np.array([239.0,4.1])
F_2x = 3.74
C_0 = 278.0
H = 100 # size of integration for AGWP calculation
epsilon = (ECS_val - TCR_val)/(TCR_val * d_array[0])
gamma = (1 - np.exp(-epsilon*H))/(epsilon*H)

# magicc like AGWP value
r0 = 32.4 # 33.6
rC = 0.019 # 0.0206
rT = 4.165 # 4.635

base_ems = RCP3_E.FossilCO2.values + RCP3_E.OtherCO2.values
pulse_ems = RCP3_E.FossilCO2.values + RCP3_E.OtherCO2.values
pulse_ems[year_val-1765] += 1. * 12 / 44

other_rf = RCP3_RF.TOTAL_ANTHRO_RF.values - RCP3_RF.CO2_RF.values

C_pulse, T_pulse = fair_scm(emissions=pulse_ems, other_rf=other_rf, tcrecs=np.array([TCR_val,ECS_val]), d=d_array, C_0=C_0, F_2x=F_2x, r0=r0, rC=rC, rT=rT)
C_base, T_base = fair_scm(emissions=base_ems, other_rf=other_rf, tcrecs=np.array([TCR_val,ECS_val]), d=d_array, C_0=C_0, F_2x=F_2x, r0=r0, rC=rC, rT=rT)

RF_net = (F_2x * np.log(C_pulse / C_0) / np.log(2.0)) - (F_2x * np.log(C_base / C_0) / np.log(2.0))
AGWP_CO2 = sp.integrate.simps(RF_net[year_val-1765:year_val+101-1765])
TCRE = (((H / AGWP_CO2) * (F_2x / TCR_val)) * (12 / 44000))**-1
print('TCR: ',TCR_val,'K\nECS: ',ECS_val,'K\ncalculated TCRE: ', TCRE, 'K/TtC')
print(H/AGWP_CO2)
# Out:
# TCR:  1.6 K
# ECS:  2.75 K
# calculated TCRE:  1.324006450562502 K/TtC
# 1184.7581636131479

# %%
fig1, ax1 = plt.subplots(figsize=(5,5))
ax1.plot([-100,1000],[-100,1000])
ax1.set_xlim(-100,1000)
ax1.set_ylim(-100,1000)
ax1.set_xlabel('\'Actual\' non-CO$_2$ budget (GtCO$_2$)')
ax1.set_ylabel('Predicted non-CO$_2$ budget (GtCO$_2$')

fig2, ax2 = plt.subplots(figsize=(5,5))
ax2.set_xlabel('delta_F')
ax2.set_ylabel('epsilon * F_bar * delta_t')

fig3, ax3 = plt.subplots(figsize=(5,5))
ax3.set_xlabel('TCRE')
ax3.set_ylabel('delta_F')

fig, ax = plt.subplots(3,2,figsize=(15,20))

num = 1000
r_vals = np.zeros((3,num))
beta = np.random.normal(1.0, 0.07, num)
r_vals[0,:] = beta*32.4
r_vals[1,:] = beta*0.019
r_vals[2,:] = beta*4.165

d_vals = np.ones((2,num))
d_vals[0,:] = 409.5
d_vals[1,:] = np.random.lognormal(1.2998, 0.506, num)

RWF_vals = np.random.normal(0.6,0.0915,num)
TCR_vals = np.random.lognormal(0.458, 0.279, num)
ECS_vals = TCR_vals/RWF_vals

total_ems = np.zeros((1000,2101-1765))
nonCO2_ems = np.zeros((1000,2101-1765))
total_temp = np.zeros((1000,2101-1765))
nonCO2_temp = np.zeros((1000,2101-1765))

for n_year_av in [20]:
    for i in [0]:#,1,3,4,5,6,7]:
        for j in range(0,len(list(co2_ems_df.filter(model=list(co2_ems_df.models())[i]).scenarios()))):
            print('i, j: ', i, ', ', j)

            single_ems = co2_ems_df.filter(model=list(co2_ems_df.models())[i], scenario=list(co2_ems_df.filter(model=list(co2_ems_df.models())[i]).scenarios())[j]).as_pandas().set_index('year').reindex(range(1765,2101)).interpolate().fillna(value=0.0).value  
            single_ems.loc[1765:2005] = (RCP3_E.FossilCO2.loc[:2005] + RCP3_E.OtherCO2.loc[:2005])*single_ems.loc[2005]/(RCP3_E.FossilCO2.loc[2005] + RCP3_E.OtherCO2.loc[2005])
            single_ems.loc[:2100] = single_ems.loc[:2100]*12/44000

            single_totalrf = total_RF_df.filter(model=list(co2_ems_df.models())[i], scenario=list(co2_ems_df.filter(model=list(co2_ems_df.models())[i]).scenarios())[j]).as_pandas().set_index('year')
            single_totalrf = single_totalrf[single_totalrf.value.values!=0.0].reindex(range(1765,2101)).interpolate().fillna(value=0.0).value
            single_totalrf.loc[1765:2005] = RCP3_RF.TOTAL_ANTHRO_RF.loc[:2005]*single_totalrf.loc[2005]/RCP3_RF.TOTAL_ANTHRO_RF.loc[2005]

            single_co2rf = co2_RF_df.filter(model=list(co2_ems_df.models())[i], scenario=list(co2_ems_df.filter(model=list(co2_ems_df.models())[i]).scenarios())[j]).as_pandas().set_index('year')
            single_co2rf = single_co2rf[single_co2rf.value.values!=0.0].reindex(range(1765,2101)).interpolate().fillna(value=0.0).value  
            single_co2rf.loc[1765:2005] = RCP3_RF.CO2_RF.loc[:2005]*single_co2rf.loc[2005]/RCP3_RF.CO2_RF.loc[2005]

            single_nonco2rf = single_totalrf - single_co2rf

            C_run, T_run = fair_scm(emissions = single_ems.values, other_rf=single_nonco2rf.values, tcrecs=np.array([TCR_val, ECS_val]), d=d_array, r0=r0,rC=rC,rT=rT,F_2x=F_2x,C_0=C_0)


            for i in range(0,num):
                if i%100 == 0:
                    print(i)
                C_total, total_temp_val = fair_scm(emissions = single_ems.values, other_rf=single_nonco2rf.values, tcrecs=np.array([TCR_vals[i], ECS_vals[i]]), d=d_vals[:,i], r0=r_vals[0,i],rC=r_vals[1,i],rT=r_vals[2,i],F_2x=F_2x,C_0=C_0)
                C_nonCO2, nonCO2_temp_val = fair_scm(other_rf=single_nonco2rf.values, tcrecs=np.array([TCR_vals[i], ECS_vals[i]]), d=d_vals[:,i], r0=r_vals[0,i], rC=r_vals[1,i], rT=r_vals[2,i], F_2x=F_2x, C_0=C_0)
                T_back_1, nonCO2_ems_val = fair_scm_emsback(single_nonco2rf.values, other_rf=single_co2rf.values,TCR=TCR_vals[i],ECS=ECS_vals[i],d1=d_vals[1,i],d2=d_vals[0,i],rC=r_vals[1,i],rT=r_vals[2,i],r0=r_vals[0,i],C_0=C_0)
                T_total_1, total_ems_val = fair_scm_emsback(single_nonco2rf.values + single_co2rf.values, TCR=TCR_vals[i],ECS=ECS_vals[i],d1=d_vals[1,i],d2=d_vals[0,i],rC=r_vals[1,i],rT=r_vals[2,i],r0=r_vals[0,i],C_0=C_0) 

                total_temp[i,:] = total_temp_val - np.mean(total_temp_val[2018-1765:2019-1765])
                nonCO2_temp[i,:] = nonCO2_temp_val - np.mean(nonCO2_temp_val[2018-1765:2019-1765])
                nonCO2_ems[i,:] = np.cumsum(nonCO2_ems_val) - np.sum(nonCO2_ems_val[:2019-1765])
                total_ems[i,:] = np.cumsum(total_ems_val) - np.sum(total_ems_val[:2019-1765])

            if np.argmax(T_run) != 335:
                T_back, E_nonco2_back = fair_scm_emsback(single_nonco2rf.values, other_rf=single_co2rf.values,TCR=TCR_val,ECS=ECS_val,d1=d_array[1],d2=d_array[0],rC=rC,rT=rT,r0=r0,C_0=C_0)

                year_temp_max = single_nonco2rf.index[np.argmax(T_run)]
                delta_t = year_temp_max - 2018

                F_0 = single_nonco2rf.loc[2018-n_year_av:2018].mean()
                F_1 = single_nonco2rf.loc[year_temp_max-n_year_av:year_temp_max].mean()
                F_bar = single_nonco2rf.loc[2018:year_temp_max].mean()

                predicted_nonco2_ems = gamma*H*(F_1 - F_0 + (epsilon*delta_t*F_bar))/(AGWP_CO2*44/12)

                delta_T = np.max(T_run) - T_run[2018-1765]
                actual_nonco2_ems = (delta_T / TCRE)*1000 - np.cumsum(single_ems.values)[year_temp_max-1765] + np.cumsum(single_ems.values)[2018-1765]
                actual_nonco2_ems2 = np.cumsum(E_nonco2_back)[year_temp_max-1765] - np.cumsum(E_nonco2_back)[2018-1765]

                predicted_co2_ems = (delta_T / TCRE)*1000 - predicted_nonco2_ems
                actual_co2_ems = np.cumsum(single_ems.values)[year_temp_max-1765] - np.cumsum(single_ems.values)[2018-1765]

                ax[0,0].plot(single_ems.index, single_ems.values*44/12, color='darkblue')
                ax[0,1].plot(single_nonco2rf.index, single_nonco2rf.values, color='darkblue')
                ax[1,0].plot(single_ems.index, (np.cumsum(single_ems.values) - np.cumsum(single_ems.values)[2018-1765])*44/12, color='darkblue')
                ax[1,1].plot(single_ems.index, (np.cumsum(E_nonco2_back) - np.cumsum(E_nonco2_back)[2018-1765])*44/12, color='darkblue')
                ax[2,0].plot(single_ems.index, T_run - T_run[2018-1765] + 1.04, color='darkblue')
                ax[2,0].plot(single_ems.index, (np.cumsum(E_nonco2_back+single_ems.values) - np.cumsum(E_nonco2_back+single_ems.values)[2018-1765])*0.001*TCRE + 1.04, color='black', linestyle=':')
    #                 ax[2,1].scatter(actual_co2_ems*44/12, predicted_co2_ems*44/12, marker='o', color='darkblue')
                ax[2,1].plot((np.cumsum(E_nonco2_back+single_ems.values) - np.cumsum(E_nonco2_back+single_ems.values)[1870-1765])*44/12, T_run - np.mean(T_run[1870-1765:1901-1765]), color='darkblue')
                ax[2,1].plot((np.cumsum(single_ems.values) - np.cumsum(single_ems.values)[1870-1765])*44/12, T_run - np.mean(T_run[1870-1765:1901-1765]), color='darkblue',linestyle=':')

                ax2.scatter(F_1 - F_0, epsilon*delta_t*F_bar, color='darkblue', s=15)
                ax3.scatter(TCRE, F_1 - F_0, color='darkblue', s=15)

                ax1.scatter(actual_nonco2_ems*44/12, predicted_nonco2_ems*44/12, marker='x', color='darkblue')
                ax1.scatter(actual_nonco2_ems2*44/12, predicted_nonco2_ems*44/12, marker='*', color='darkblue')



                T_back, E_total_back = fair_scm_emsback(single_totalrf.values,TCR=TCR_val,ECS=ECS_val,d1=d_array[1],d2=d_array[0],rC=rC,rT=rT,r0=r0,C_0=C_0)
                E_nonco2_alternate = E_total_back - single_ems.values
                #ax[1,1].plot(np.arange(1765,2101), (np.cumsum(E_nonco2_alternate) - np.cumsum(E_nonco2_alternate)[2018-1765])*44/12, color='darkblue', linestyle=':')
                ax1.scatter((np.cumsum(E_nonco2_alternate)[year_temp_max-1765] - np.cumsum(E_nonco2_alternate)[2018-1765])*44/12, predicted_nonco2_ems*44/12, marker='o', color='darkblue')

    #                 ax[1,1].scatter(year_temp_max, np.cumsum(E_nonco2_alternate)[year_temp_max-1765] - np.cumsum(E_nonco2_alternate)[2018-1765], zorder = 10, color='green', s=8)

                #ax[1,1].scatter(year_temp_max, predicted_nonco2_ems*44/12, zorder = 10, color='white', edgecolor='black', linewidth=1.0, s=25)

    #                 ax[1,1].scatter(year_temp_max, actual_nonco2_ems*44/12, zorder = 10, color='magenta', s=10)
    #                 ax[1,1].scatter(year_temp_max, actual_nonco2_ems2*44/12, zorder = 10, color='green', s=10)

                delta_fs = np.append(delta_fs, F_1 - F_0)

                print('CO2: ', (np.cumsum(single_ems.values)[2100-1765] - np.cumsum(single_ems.values)[2018-1765])*44/12)
                print('non-CO2: ', (np.cumsum(E_nonco2_back)[2100-1765] - np.cumsum(E_nonco2_back)[2018-1765])*44/12)
    #                 print((np.cumsum(E_nonco2_back+single_ems.values) - np.cumsum(E_nonco2_back+single_ems.values)[2018-1765])[year_temp_max-1765])
    #                 print((np.cumsum(E_nonco2_back) - np.cumsum(E_nonco2_back)[2018-1765])[year_temp_max-1765])
    # print('mean=',np.mean([1.4942851100577366,1.5449778429229493,1.5317666948284399,1.5394267857189985,1.4367083812061985,1.4375890539538407,1.478125614629406,1.4770847648264573,1.5051667954040988,1.5049787451554082,1.5942726336228301,1.5893835194252728]))
# Out:
# i, j:  0 ,  0
# 0
# 100
# 200
# 300
# overflow encountered in multiply
# 400
# 500
# 600
# 700
# 800
# 900
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-269f723c88e8> in <module>
#      96                 ax3.scatter(TCRE, F_1 - F_0, color='darkblue', s=15)
#      97
# ---> 98                 ax1.scatter(actual_nonco2_ems*44/12, predicted_nonco2_ems*44/12, marker='x', color='darkblue')
#      99                 ax1.scatter(actual_nonco2_ems2*44/12, predicted_nonco2_ems*44/12, marker='*', color='darkblue')
#     100
#
# NameError: name 'ax1' is not defined

# %%
fig_non_co2, ax_non_co2 = plt.subplots(3,2,figsize=(20,20))

total_temp_95 = np.percentile(total_temp, 95, axis=0)
total_temp_66 = np.percentile(total_temp, 67, axis=0)
total_temp_5 = np.percentile(total_temp, 5, axis=0)

nonCO2_temp_95 = np.percentile(nonCO2_temp, 95, axis=0)
nonCO2_temp_66 = np.percentile(nonCO2_temp, 67, axis=0)
nonCO2_temp_5 = np.percentile(nonCO2_temp, 5, axis=0)

total_ems_95 = np.percentile(total_ems, 95, axis=0)
total_ems_66 = np.percentile(total_ems, 67, axis=0)
total_ems_5 = np.percentile(total_ems, 5, axis=0)

nonCO2_ems_95 = np.percentile(nonCO2_ems, 95, axis=0)
nonCO2_ems_66 = np.percentile(nonCO2_ems, 67, axis=0)
nonCO2_ems_5 = np.percentile(nonCO2_ems, 5, axis=0)

ax_non_co2[0,0].plot(np.arange(1765,2101), total_temp_66, color='royalblue')
ax_non_co2[0,0].fill_between(np.arange(1765,2101), total_temp_5, total_temp_95, alpha=0.4, color='royalblue')

ax_non_co2[1,0].plot(np.arange(1765,2101), nonCO2_temp_66, color='royalblue')
ax_non_co2[1,0].fill_between(np.arange(1765,2101), nonCO2_temp_5, nonCO2_temp_95, alpha=0.4, color='royalblue')

ax_non_co2[0,1].plot(np.arange(1765,2101), total_ems_66, color='royalblue')
ax_non_co2[0,1].fill_between(np.arange(1765,2101), total_ems_5, total_ems_95, alpha=0.4, color='royalblue')

ax_non_co2[1,1].plot(np.arange(1765,2101), nonCO2_ems_66, color='royalblue')
ax_non_co2[1,1].fill_between(np.arange(1765,2101), nonCO2_ems_5, nonCO2_ems_95, alpha=0.4, color='royalblue')

# ax_non_co2[0,2].plot(np.arange(1765,2101),np.cumsum(total_ems_66), color='royalblue')
# ax_non_co2[0,2].fill_between(np.arange(1765,2101), np.cumsum(total_ems_5), np.cumsum(total_ems_95), alpha=0.4, color='royalblue')

# ax_non_co2[1,2].plot(np.arange(1765,2101), np.cumsum(nonCO2_ems_66), color='royalblue')
# ax_non_co2[1,2].fill_between(np.arange(1765,2101), np.cumsum(nonCO2_ems_5), np.cumsum(nonCO2_ems_95), alpha=0.4, color='royalblue')


ax_non_co2[2,0].plot(total_ems_66, total_temp_66, color='royalblue')
ax_non_co2[2,0].fill_between(total_ems_5, total_temp_5, total_temp_95, alpha=0.4, color='royalblue')
ax_non_co2[2,0].fill_between(total_ems_95, total_temp_5, total_temp_95, alpha=0.4, color='red')

ax_non_co2[2,0].plot(np.cumsum(single_ems.values), total_temp_66, color='black')

ax_non_co2[2,1].plot(total_ems_66[:np.argmax(total_temp_66)+1], total_temp_66[:np.argmax(total_temp_66)+1], color='royalblue')
# ax_non_co2[2,1].fill_between(np.cumsum(total_ems_5[:np.argmax(total_temp_5)+1]), total_temp_5[:np.argmax(total_temp_5)+1], total_temp_95[:np.argmax(total_temp_5)+1], alpha=0.4, color='royalblue')
# ax_non_co2[2,1].fill_between(np.cumsum(total_ems_95[:np.argmax(total_temp_95)+1]), total_temp_5[:np.argmax(total_temp_95)+1], total_temp_95[:np.argmax(total_temp_95)+1], alpha=0.4, color='red')

ax_non_co2[2,1].plot(np.cumsum(single_ems.values[2018-1765:np.argmax(total_temp_66)+1]), total_temp_66[2018-1765:np.argmax(total_temp_66)+1], color='black')


z_top = np.polyfit(total_ems_5[2018-1765:np.argmax(total_temp_5)+1], total_temp_95[2018-1765:np.argmax(total_temp_5)+1], 1)
z_bottom = np.polyfit(total_ems_95[2018-1765:np.argmax(total_temp_95)+1], total_temp_5[2018-1765:np.argmax(total_temp_95)+1], 1)
z_66 = np.polyfit(total_ems_66[2018-1765:np.argmax(total_temp_66)+1], total_temp_66[2018-1765:np.argmax(total_temp_66)+1], 1)

ax_non_co2[2,1].fill_between(np.arange(0,1101,100), np.arange(0,1101,100)*z_top[0], np.arange(0,1101,100)*z_bottom[0], color='green', alpha=0.3)
ax_non_co2[2,1].plot(np.arange(0,1101,100), np.arange(0,1101,100)*z_66[0], color='green')

ax_non_co2[2,1].plot([0,1000],[1.5,1.5], linestyle=':', color='black')
ax_non_co2[2,1].plot([1000,1000],[0,1.5], linestyle=':', color='black')

ax_non_co2[0,0].set_xlim(2018,2100)
ax_non_co2[1,0].set_xlim(2018,2100)
ax_non_co2[2,0].set_xlim(0,400)
ax_non_co2[0,1].set_xlim(2018,2100)
ax_non_co2[1,1].set_xlim(2018,2100)
ax_non_co2[2,1].set_xlim(0,400)

# ax_non_co2[0,0].set_ylim(-0.5,0.5)
# ax_non_co2[1,0].set_ylim(-0.15,0.15)
# # ax_non_co2[2,0].set_ylim(2018,2100)
# ax_non_co2[0,1].set_ylim(-200,300)
# ax_non_co2[1,1].set_ylim(-35,60)
ax_non_co2[2,1].set_ylim(0,0.7)


# for CO2-fe technique

ax_non_co2[2,1].plot([0,665],[1.0,1.0], color='black', linestyle=':')
ax_non_co2[2,1].plot([665,665],[0,1.0], color='black', linestyle=':')
# ax_non_co2[2,1].set_xlim(0,1000)
# ax_non_co2[2,1].set_ylim(0,2)

print(nonCO2_ems_5[np.argmin(np.abs(total_temp_66-1.0))])
print(nonCO2_ems_95[np.argmin(np.abs(total_temp_66-1.0))])

ax_non_co2[2,1].plot([665-nonCO2_ems_5[np.argmin(np.abs(total_temp_66-1.0))], 665-nonCO2_ems_5[np.argmin(np.abs(total_temp_66-1.0))]],[0,0.25], linestyle='--', color='black')
ax_non_co2[2,1].plot([665-nonCO2_ems_95[np.argmin(np.abs(total_temp_66-1.0))], 665-nonCO2_ems_95[np.argmin(np.abs(total_temp_66-1.0))]],[0,0.25], linestyle='--', color='black')



# for rogelj technique

print(nonCO2_ems_66[np.argmin(np.abs(total_temp_5-1.0))])
print(nonCO2_ems_66[np.argmin(np.abs(total_temp_95-1.0))])

# ax_non_co2[2,1].plot([0,665],[1.0 - nonCO2_temp_5[np.argmin(np.abs(total_temp_66-1.0))],1.0 - nonCO2_temp_5[np.argmin(np.abs(total_temp_66-1.0))]], color='red', linestyle=':')
# ax_non_co2[2,1].plot([665,665],[0,1.0 - nonCO2_temp_5[np.argmin(np.abs(total_temp_66-1.0))]], color='red', linestyle=':')
# ax_non_co2[2,1].set_xlim(0,1000)
# ax_non_co2[2,1].set_ylim(0,2)

# ax_non_co2[2,1].plot([665-nonCO2_ems_5[np.argmin(np.abs(total_temp_66-1.0))], 665-nonCO2_ems_5[np.argmin(np.abs(total_temp_66-1.0))]],[0,0.25], linestyle='--', color='black')
# ax_non_co2[2,1].plot([665-nonCO2_ems_95[np.argmin(np.abs(total_temp_66-1.0))], 665-nonCO2_ems_95[np.argmin(np.abs(total_temp_66-1.0))]],[0,0.25], linestyle='--', color='black')


# CO2 RF not giving same CUMSUM ems as sum of reported CO2 ems?
ax_non_co2[0,0].plot(np.arange(1765,2101), 1.6*0.001*(np.cumsum(single_ems.values) - np.sum(single_ems.values[:2019-1765]) + nonCO2_ems_66), color='red')


# ax_non_co2[2,1].fill_between(np.arange(1765,2101), nonCO2_ems_5, nonCO2_ems_95, alpha=0.4, color='royalblue')


plt.figure(figsize=(10,10))

plt.plot(np.cumsum(single_ems.values) - np.sum(single_ems.values[:1971-1765]), np.cumsum(fair_scm_emsback(single_co2rf.values, other_rf=single_nonco2rf.values)[1]) - np.sum(fair_scm_emsback(single_co2rf.values, other_rf=single_nonco2rf.values)[1][:1971-1765]))
plt.plot([0,1000], [0,1000], linestyle=':', color='black')








print('\n',np.max(total_temp_66), np.argmax(total_temp_66))
print(nonCO2_temp_66[np.argmax(total_temp_66)])

print(total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print(total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print(total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])
print(':')
print(np.sum(single_ems.values[2018-1765:np.argmax(total_temp_66)+1]))
print(':')
print((total_temp_66[np.argmax(total_temp_66)] - nonCO2_temp_66[np.argmax(total_temp_66)]))

# print(np.argmin(np.abs((total_temp_66 - total_temp_66[np.argmax(total_temp_66)] + nonCO2_temp_66[np.argmax(total_temp_66)]))))
print(total_ems_66[np.argmin(np.abs((total_temp_66 - total_temp_66[np.argmax(total_temp_66)] + nonCO2_temp_66[np.argmax(total_temp_66)])))])


fig_test, ax_test = plt.subplots(2,2,figsize=(14,14))
ax_test[0,0].plot(np.arange(1765,2101), total_temp_66, color='royalblue')
ax_test[0,0].fill_between(np.arange(1765,2101), total_temp_5, total_temp_95, alpha=0.4, color='royalblue')

ax_test[0,0].plot(np.arange(1765,2101), nonCO2_temp_66, color='orange')
ax_test[0,0].fill_between(np.arange(1765,2101), nonCO2_temp_5, nonCO2_temp_95, alpha=0.4, color='orange')

ax_test[0,1].plot(np.arange(1765,2101), total_ems_66, color='royalblue')
ax_test[0,1].fill_between(np.arange(1765,2101), total_ems_5, total_ems_95, alpha=0.4, color='royalblue')

ax_test[0,1].plot(np.arange(1765,2101), nonCO2_ems_66, color='orange')
ax_test[0,1].fill_between(np.arange(1765,2101), nonCO2_ems_5, nonCO2_ems_95, alpha=0.4, color='orange')

ax_test[0,1].fill_between(np.arange(1765,2101), total_ems_66-nonCO2_ems_5, total_ems_66-nonCO2_ems_95, color='red', alpha=0.4)
ax_test[0,0].fill_between(np.arange(1765,2101), total_temp_66-nonCO2_temp_5, total_temp_66-nonCO2_temp_95, color='red', alpha=0.4)

ax_test[0,1].plot(np.arange(1765,2101), total_ems_66-nonCO2_ems_66, color='red')
ax_test[0,0].plot(np.arange(1765,2101), total_temp_66-nonCO2_temp_66, color='red')

ax_test[0,0].set_xlim(2000,2100)
ax_test[0,0].set_ylim(-0.4,1.2)
ax_test[1,0].set_xlim(-100,450)
# ax_test[2,0].set_xlim(0,400)
ax_test[0,1].set_xlim(2000,2100)
ax_test[0,1].set_ylim(-200,600)
ax_test[1,0].set_ylim(-0.2,0.6)
# ax_test[1,1].set_xlim(2010,2100)
# ax_test[2,1].set_xlim(0,400)




def func(x, a):
    return a * x


ax_test[1,0].set_xlim(-100,450)
ax_test[1,0].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2018-1765:np.argmax(total_temp_66)+1], total_temp_66[2018-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2018-1765:np.argmax(total_temp_66)+1], total_temp_95[2018-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2018-1765:np.argmax(total_temp_66)+1], total_temp_5[2018-1765:np.argmax(total_temp_66)+1])
ax_test[1,0].plot(np.arange(-100,400), np.arange(-100,400)*popt_66[0], linestyle=':', color='red')
ax_test[1,0].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
ax_test[1,0].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

ax_test[1,0].plot(total_ems_66, total_temp_66, color='royalblue')
ax_test[1,0].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
ax_test[1,0].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[1,0].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

ax_test[1,0].plot(np.cumsum(single_ems.values)[2018-1765:np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2018-1765]), total_temp_66[2018-1765:np.argmax(total_temp_66)+1], color='black')


ax_test[1,0].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle=':')
ax_test[1,0].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle=':')

ax_test[1,0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
ax_test[1,0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
ax_test[1,0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])


ax_test[1,0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')

ax_test[1,0].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,0].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,0].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')












def func(x, a):
    return a * x


ax_test[1,1].set_xlim(-100,450)
ax_test[1,1].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2018-1765:np.argmax(total_temp_66)+1], total_temp_66[2018-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2018-1765:np.argmax(total_temp_66)+1], total_temp_95[2018-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2018-1765:np.argmax(total_temp_66)+1], total_temp_5[2018-1765:np.argmax(total_temp_66)+1])
ax_test[1,1].plot(np.arange(-100,400), np.arange(-100,400)*popt_66[0], linestyle=':', color='red')
ax_test[1,1].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
ax_test[1,1].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

# ax_test[1,1].plot(total_ems_66, total_temp_66, color='royalblue')
# ax_test[1,1].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
# ax_test[1,1].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[1,1].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

ax_test[1,1].plot(np.cumsum(single_ems.values)[2018-1765:np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2018-1765]), total_temp_66[2018-1765:np.argmax(total_temp_66)+1], color='black')


ax_test[1,1].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle=':')
ax_test[1,1].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle=':')

ax_test[1,1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
ax_test[1,1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
ax_test[1,1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])


ax_test[1,1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')

ax_test[1,1].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,1].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
ax_test[1,1].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')
# Out:
# 25.53417091874731
# 38.26629129056461
# 37.072174054861826
# 28.32532743780708
#
#  0.3001339221250846 271
# 0.07417067612104183
# 136.16233065776822
# 143.93371418627007
# 131.2015938144528
# :
# 143.59048499454545
# :
# 0.22596324600404277
# 146.3217525364294
#
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528
#
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528

# %%
fig_test, ax_test = plt.subplots(1,2,figsize=(9,4.5))


def func(x, a):
    return a * x

ax_test[1].set_xlim(-100,450)
ax_test[1].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2010-1765:np.argmax(total_temp_66)+1], total_temp_66[2010-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2010-1765:np.argmax(total_temp_66)+1], total_temp_95[2010-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2010-1765:np.argmax(total_temp_66)+1], total_temp_5[2010-1765:np.argmax(total_temp_66)+1])
ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_66[0], linestyle='-', color='black', linewidth=3)
# ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
# ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

# ax_test[1,1].plot(total_ems_66, total_temp_66, color='royalblue')
# ax_test[1,1].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
# ax_test[1,1].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[1].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

# ax_test[1].plot(np.cumsum(single_ems.values)[2010-1765:np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2010-1765]), total_temp_66[2010-1765:np.argmax(total_temp_66)+1], color='black')
# ax_test[1].scatter(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2010-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', facecolor='none')

ax_test[1].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)
ax_test[1].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)

# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])



ax_test[1].plot(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2019-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', linestyle='-.')
ax_test[1].scatter(np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), total_temp_66[np.argmax(total_temp_66)+1], color='black', facecolor='black', s=70, zorder=10)
ax_test[1].plot([np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765])], [-0.2,total_temp_66[np.argmax(total_temp_66)+1]], color='black', linestyle=':', linewidth=4)




# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')

# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')







ax_test[0].set_xlim(-100,450)
ax_test[0].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2010-1765:np.argmax(total_temp_66)+1], total_temp_66[2010-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2010-1765:np.argmax(total_temp_66)+1], total_temp_95[2010-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2010-1765:np.argmax(total_temp_66)+1], total_temp_5[2010-1765:np.argmax(total_temp_66)+1])
ax_test[0].plot(np.arange(-100,500), np.arange(-100,500)*popt_66[0], linestyle='-', color='black', linewidth=3)
# ax_test[0].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
# ax_test[0].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

# ax_test[1,1].plot(total_ems_66, total_temp_66, color='royalblue')
# ax_test[1,1].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
# ax_test[1,1].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[0].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

ax_test[0].plot(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2019-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', linestyle='-.')
ax_test[0].scatter(np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), total_temp_66[np.argmax(total_temp_66)+1], color='black', facecolor='black', s=70, zorder=10)
ax_test[0].plot([np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765])], [-0.2,total_temp_66[np.argmax(total_temp_66)+1]], color='black', linestyle=':', linewidth=4)


ax_test[0].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)
# ax_test[0].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle=':')

# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])


ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)
ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)
ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)

# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)
# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)
# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)

ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2,0.6] , color='red', linestyle=':', linewidth=2.5)
ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2,0.6], color='red', linestyle=':', linewidth=2.5)
ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2,0.6], color='red', linestyle=':', linewidth=2.5)



# ax_test[0].axhline(y=0, color='grey', alpha=0.4)
# ax_test[0].axvline(x=0, color='grey', alpha=0.4)
ax_test[0].set_xlim(0,300)
ax_test[0].set_ylim(0,0.5)
ax_test[1].set_xlim(0,300)
ax_test[1].set_ylim(0,0.5)

# ax_test[0].set_xlabel('Cumulative CO$_2$ emissions (GtC)', fontsize=12)
ax_test[0].set_ylabel('Warming anomaly ($^{\circ}$C)', fontsize=12)
# ax_test[1].set_xlabel('Cumulative CO$_2$ emissions (GtC)', fontsize=12)
ax_test[1].set_ylabel('Warming anomaly ($^{\circ}$C)', fontsize=12)
ax_test[0].set_xticks([])
ax_test[1].set_xticks([])


ax_test[0].annotate('', xy=(25, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]), xytext=(25, np.max(total_temp_66)),
            arrowprops=dict(color='red', shrink=0.03))

ax_test[1].annotate('', xy=((np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)])/popt_66, 0.05), xytext=(np.max(total_temp_66)/popt_66, 0.05),
            arrowprops=dict(color='royalblue', shrink=0.03))

axtest_01 = ax_test[0].twiny()
axtest_01.set_xlim(0,300*44/12)
axtest_01.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=12)

axtest_11 = ax_test[1].twiny()
axtest_11.set_xlim(0,300*44/12)
axtest_11.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=12)


dx = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)] - total_ems_66[np.argmax(total_temp_66)] + nonCO2_ems_5[np.argmax(total_temp_66)]) / 2.
x = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)] + total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]) / 2.
e1 = ax_test[1].errorbar(x, -0.05, xerr=dx, fmt='none', ecolor='royalblue', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)] - total_ems_66[np.argmax(total_temp_66)] + nonCO2_ems_5[np.argmax(total_temp_66)]) / 2.
x = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)] + total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]) / 2.
e1 = ax_test[0].errorbar(x, -0.05, xerr=dx, fmt='none', ecolor='royalblue', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top - (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom) / 2.
x = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top + (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom) / 2.
e1 = ax_test[0].errorbar(x, -0.02, xerr=dx, fmt='none', ecolor='red', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top - (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom) / 2.
x = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top + (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom) / 2.
e1 = ax_test[1].errorbar(x, -0.02, xerr=dx, fmt='none', ecolor='red', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)

# fig_test.savefig('schematic.pdf', dpi=300)
# Out:
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528
#
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528

# %%
fig_test, ax_test = plt.subplots(1,2,figsize=(9,4.5))


def func(x, a):
    return a * x

ax_test[1].set_xlim(-100,450)
ax_test[1].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2010-1765:np.argmax(total_temp_66)+1], total_temp_66[2010-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2010-1765:np.argmax(total_temp_66)+1], total_temp_95[2010-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2010-1765:np.argmax(total_temp_66)+1], total_temp_5[2010-1765:np.argmax(total_temp_66)+1])
ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_66[0], linestyle='-', color='black', linewidth=3)
# ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
# ax_test[1].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

# ax_test[1,1].plot(total_ems_66, total_temp_66, color='royalblue')
# ax_test[1,1].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
# ax_test[1,1].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[1].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

# ax_test[1].plot(np.cumsum(single_ems.values)[2010-1765:np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2010-1765]), total_temp_66[2010-1765:np.argmax(total_temp_66)+1], color='black')
# ax_test[1].scatter(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2010-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', facecolor='none')

ax_test[1].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)
ax_test[1].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)

# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
# ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.52], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)
ax_test[1].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.6], color='royalblue', linestyle=':', linewidth=2.5)

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])



ax_test[1].plot(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2019-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', linestyle='-.')
ax_test[1].scatter(np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), total_temp_66[np.argmax(total_temp_66)+1], color='black', facecolor='black', s=70, zorder=10)
ax_test[1].plot([np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765])], [-0.2,total_temp_66[np.argmax(total_temp_66)+1]], color='black', linestyle=':', linewidth=4)




# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')

# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':')
# ax_test[1].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':')







ax_test[0].set_xlim(-100,450)
ax_test[0].set_ylim(-0.2,0.6)

popt_66, pcov = curve_fit(func, total_ems_66[2010-1765:np.argmax(total_temp_66)+1], total_temp_66[2010-1765:np.argmax(total_temp_66)+1])
popt_top, pcov = curve_fit(func, total_ems_5[2010-1765:np.argmax(total_temp_66)+1], total_temp_95[2010-1765:np.argmax(total_temp_66)+1])
popt_bottom, pcov = curve_fit(func, total_ems_95[2010-1765:np.argmax(total_temp_66)+1], total_temp_5[2010-1765:np.argmax(total_temp_66)+1])
ax_test[0].plot(np.arange(-100,500), np.arange(-100,500)*popt_66[0], linestyle='-', color='black', linewidth=3)
# ax_test[0].plot(np.arange(-100,400), np.arange(-100,400)*popt_top[0], linestyle=':', color='red')
# ax_test[0].plot(np.arange(-100,400), np.arange(-100,400)*popt_bottom[0], linestyle=':', color='red')

# ax_test[1,1].plot(total_ems_66, total_temp_66, color='royalblue')
# ax_test[1,1].plot(total_ems_5, total_temp_95, color='royalblue', alpha=0.4)
# ax_test[1,1].plot(total_ems_95, total_temp_5, color='royalblue', alpha=0.4)

ax_test[0].fill_between(np.arange(-100,450), np.arange(-100,450)*popt_bottom[0], np.arange(-100,450)*popt_top[0], color='grey', alpha=0.4)

ax_test[0].plot(np.cumsum(single_ems.values)[:np.argmax(total_temp_66)+1:2] - np.sum(single_ems.values[:2019-1765]), total_temp_66[:np.argmax(total_temp_66)+1:2], color='black', linestyle='-.')
ax_test[0].scatter(np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), total_temp_66[np.argmax(total_temp_66)+1], color='black', facecolor='black', s=70, zorder=10)
ax_test[0].plot([np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765]), np.cumsum(single_ems.values)[np.argmax(total_temp_66)+1] - np.sum(single_ems.values[:2019-1765])], [-0.2,total_temp_66[np.argmax(total_temp_66)+1]], color='black', linestyle=':', linewidth=4)


ax_test[0].plot([-100,np.max(total_temp_66)/popt_66],[np.max(total_temp_66), np.max(total_temp_66)], color='black', linestyle='-', linewidth=1.5)
# ax_test[0].plot([np.max(total_temp_66)/popt_66, np.max(total_temp_66)/popt_66],[-0.2, np.max(total_temp_66)], color='black', linestyle=':')

# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')
# ax_test[0].plot([total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)], total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]],[-0.2, 0.53], color='black', linestyle=':')

print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_66[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)])
print('\n', total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)])


ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)
ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66], [np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)
ax_test[0].plot([-100,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66], [np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)], np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle='-', linewidth=1.5)

# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)
# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_top], [-0.2, np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)
# ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_bottom], [-0.2, np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)]], color='red', linestyle=':', linewidth=2.5)

ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66,(np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)+1])/popt_66], [-0.2,0.6] , color='red', linestyle=':', linewidth=2.5)
ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66,(np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66], [-0.2,0.6], color='red', linestyle=':', linewidth=2.5)
ax_test[0].plot([(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66,(np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66], [-0.2,0.6], color='red', linestyle=':', linewidth=2.5)



# ax_test[0].axhline(y=0, color='grey', alpha=0.4)
# ax_test[0].axvline(x=0, color='grey', alpha=0.4)
ax_test[0].set_xlim(0,300)
ax_test[0].set_ylim(0,0.5)
ax_test[1].set_xlim(0,300)
ax_test[1].set_ylim(0,0.5)

# ax_test[0].set_xlabel('Cumulative CO$_2$ emissions (GtC)', fontsize=12)
ax_test[0].set_ylabel('Warming anomaly ($^{\circ}$C)', fontsize=12)
# ax_test[1].set_xlabel('Cumulative CO$_2$ emissions (GtC)', fontsize=12)
ax_test[1].set_ylabel('Warming anomaly ($^{\circ}$C)', fontsize=12)
ax_test[0].set_xticks([])
ax_test[1].set_xticks([])


ax_test[0].annotate('', xy=(25, np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)]), xytext=(25, np.max(total_temp_66)),
            arrowprops=dict(color='red', shrink=0.03))

ax_test[1].annotate('', xy=((np.max(total_temp_66) - nonCO2_temp_66[np.argmax(total_temp_66)])/popt_66, 0.05), xytext=(np.max(total_temp_66)/popt_66, 0.05),
            arrowprops=dict(color='royalblue', shrink=0.03))

axtest_01 = ax_test[0].twiny()
axtest_01.set_xlim(0,300*44/12)
axtest_01.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=12)

axtest_11 = ax_test[1].twiny()
axtest_11.set_xlim(0,300*44/12)
axtest_11.set_xlabel('Cumulative CO$_2$ emissions (GtCO$_2$)', fontsize=12)


dx = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)] - total_ems_66[np.argmax(total_temp_66)] + nonCO2_ems_5[np.argmax(total_temp_66)]) / 2.
x = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)] + total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]) / 2.
e1 = ax_test[1].errorbar(x, -0.05, xerr=dx, fmt='none', ecolor='royalblue', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)] - total_ems_66[np.argmax(total_temp_66)] + nonCO2_ems_5[np.argmax(total_temp_66)]) / 2.
x = (total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_5[np.argmax(total_temp_66)] + total_ems_66[np.argmax(total_temp_66)] - nonCO2_ems_95[np.argmax(total_temp_66)]) / 2.
e1 = ax_test[0].errorbar(x, -0.05, xerr=dx, fmt='none', ecolor='royalblue', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66 - (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66) / 2.
x = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66 + (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66) / 2.
e1 = ax_test[0].errorbar(x, -0.02, xerr=dx, fmt='none', ecolor='red', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)
    
dx = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66 - (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66) / 2.
x = ((np.max(total_temp_66) - nonCO2_temp_5[np.argmax(total_temp_66)])/popt_66 + (np.max(total_temp_66) - nonCO2_temp_95[np.argmax(total_temp_66)])/popt_66) / 2.
e1 = ax_test[1].errorbar(x, -0.02, xerr=dx, fmt='none', ecolor='red', alpha=0.8, elinewidth=3, capsize=5)
for b in e1[1]:
    b.set_clip_on(False)
for b in e1[2]:
    b.set_clip_on(False)

# fig_test.savefig('schematic.pdf', dpi=300)
# Out:
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
# invalid escape sequence \c
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528
#
#  136.16233065776822
#
#  143.93371418627007
#
#  131.2015938144528
